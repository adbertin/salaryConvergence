# %% [markdown]
# <a href="https://colab.research.google.com/github/adbertin/salaryConvergence/blob/main/Estimated_Wages_Computation_%2B_Norway_adjustment_%2B_Comparison_to_true_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os

# --- 1. LOAD CSV FILES ---
df_emp = pd.read_csv('~/Documents/Project_Wage_Convergence/employment_ratio.csv')
df_gdp = pd.read_csv('~/Documents/Project_Wage_Convergence/gdp_per_capita_ppp.csv')
df_labsh = pd.read_csv('~/Documents/Project_Wage_Convergence/pwt_labor_share_extended.csv')
df_hours = pd.read_csv('~/Downloads/Hours_extrapolated_1990_2023_selected.csv')


# --- 2. NORMALIZE COLUMN NAMES ---
df_emp.columns = df_emp.columns.str.strip().str.lower()
df_gdp.columns = df_gdp.columns.str.strip().str.lower()
df_labsh.columns = df_labsh.columns.str.strip().str.lower()
df_hours.columns = df_hours.columns.str.strip().str.lower()

print("EMP columns:", df_emp.columns.tolist())
print("GDP columns:", df_gdp.columns.tolist())
print("LABSH columns:", df_labsh.columns.tolist())
print("HOURS columns:", df_hours.columns.tolist())  # Check how the working hours file is structured

# --- 3. MELT (UNPIVOT) THE WIDE DATAFRAMES ---
# For Employment ratio & GDP, we assume: "country code", "country", "series name", plus year columns.
df_emp_melt = df_emp.melt(
    id_vars=["country code", "country", "series name"],
    var_name="year",
    value_name="empratio"
)

df_gdp_melt = df_gdp.melt(
    id_vars=["country code", "country", "series name"],
    var_name="year",
    value_name="gdpcap"
)

# For Labor share (PWT), we assume: "iso code", "country", "variable code", "variable name"
df_labsh_melt = df_labsh.melt(
    id_vars=["iso code", "country", "variable code", "variable name"],
    var_name="year",
    value_name="laborshare"
)

# For Penn working hours, from your screenshot:
# "Country" in first column, then columns for each year (1990, 1991, ...)
df_hours_melt = df_hours.melt(
    id_vars=["country"],      # keep "country" fixed
    var_name="year",          # melted columns become "year"
    value_name="whours"       # melted values become "whours"
)

# --- 4. RENAME / ALIGN COLUMNS FOR CONSISTENCY ---
df_emp_melt.rename(columns={"country code": "wb_countrycode"}, inplace=True)
df_gdp_melt.rename(columns={"country code": "wb_countrycode"}, inplace=True)
df_labsh_melt.rename(columns={"iso code": "iso_code"}, inplace=True)
# For hours, if you have a separate ISO code or if you rely on "country" only,
# you might later need to do name matching or rename "country" to "iso_code".
# For simplicity, let's assume we match on "country" + "year".

# --- 5. CREATE A COMMON MERGE KEY ---
df_emp_melt["iso_code"] = df_emp_melt["wb_countrycode"]
df_gdp_melt["iso_code"] = df_gdp_melt["wb_countrycode"]

# Convert "year" columns to numeric
for df_ in [df_emp_melt, df_gdp_melt, df_labsh_melt, df_hours_melt]:
    df_["year"] = pd.to_numeric(df_["year"], errors="coerce")

# --- 6. MERGE EMP + GDP + LABOR SHARE ---
df_merged_1 = pd.merge(
    df_emp_melt[["iso_code", "country", "year", "empratio"]],
    df_gdp_melt[["iso_code", "country", "year", "gdpcap"]],
    on=["iso_code", "year"],
    how="outer"
)

df_merged = pd.merge(
    df_merged_1,
    df_labsh_melt[["iso_code", "year", "laborshare"]],
    on=["iso_code", "year"],
    how="outer"
)

# --- 7. CONVERT TO NUMERIC (if not already) ---
df_merged["empratio"]   = pd.to_numeric(df_merged["empratio"], errors="coerce")
df_merged["gdpcap"]     = pd.to_numeric(df_merged["gdpcap"], errors="coerce")
df_merged["laborshare"] = pd.to_numeric(df_merged["laborshare"], errors="coerce")

# >>>>> INSERTED CODE: Unify country columns <<<<<
# Rename one of the duplicate country columns to "country" and drop the other
df_merged.rename(columns={"country_x": "country"}, inplace=True)
if "country_y" in df_merged.columns:
    df_merged.drop(columns=["country_y"], inplace=True)
# -----------------------------------------------------

# --- 8. MERGE WORKING HOURS ---
# Merge on "country" + "year"
df_final = pd.merge(
    df_merged,
    df_hours_melt[["country", "year", "whours"]],
    on=["country", "year"],
    how="inner"  # or "outer" if you want to keep all rows and then filter missing
)

# --- 9. FILTER OUT ROWS THAT LACK ANY COMPONENT (we only want complete data) ---
df_final = df_final.dropna(subset=["empratio", "gdpcap", "laborshare", "whours"])

# --- 10. COMPUTE ESTIMATED HOURLY WAGE ---
df_final["empratio_fraction"] = df_final["empratio"] / 100.0

def compute_est_hourly_wage(row):
    print(
        f"{row['country']}, {row['year']}, "
        f"empratio={row['empratio']}, gdpcap={row['gdpcap']}, "
        f"laborshare={row['laborshare']}, whours={row['whours']}"
    )
    annual_wage = (row["gdpcap"] * row["laborshare"]) / (row["empratio"] / 100.0)
    hourly_wage = annual_wage / row["whours"]
    print("Hourly wage =>", hourly_wage)
    return hourly_wage

df_final["estimated_hourly_wage"] = df_final.apply(compute_est_hourly_wage, axis=1)

# --- 10a. APPLY LOGARITHMIC TRANSFORMATION ---
# Using a log transformation for robustness
df_final["log_estimated_hourly_wage"] = np.log(df_final["estimated_hourly_wage"])

# --- 11. EXPORT RESULTS ---
output_file = "~/Downloads/Countries_Wages_Estimates_GOOD.csv"
df_final.to_csv(output_file, index=False)
print(f"Done! '{output_file}' created with 'estimated_hourly_wage' and its log-transformation.")

# 12. LOAD OECD BENCHMARK

df_oecd = pd.read_csv(os.path.expanduser('~/Documents/Project_Wage_Convergence/OECD_wages_merged.csv'))
df_oecd.rename(columns={'Country':'country','Wages':'oecd_annual_wage','Year':'year'}, inplace=True)
df_oecd['year'] = pd.to_numeric(df_oecd['year'], errors='coerce')

# 13. MERGE INTO df_compare
df_compare = pd.merge(
    df_final,
    df_oecd[['country','year','oecd_annual_wage']],
    on=['country','year'],
    how='inner'
)

# 14. COMPUTE OECD HOURLY WAGE
df_compare['oecd_hourly_wage'] = df_compare['oecd_annual_wage'] / df_compare['whours']

# Now df_compare is available for groupbys and plotting
print("df_compare created with", len(df_compare), "rows")
# Out:
# EMP columns: ['country', 'country code', 'series name', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
# GDP columns: ['country', 'country code', 'series name', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
# LABSH columns: ['iso code', 'country', 'variable code', 'variable name', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
# HOURS columns: ['country', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
# Angola, 1991, empratio=64.287, gdpcap=7218.441432, laborshare=0.284384667873383, whours=2100.0
# Hourly wage => 1.5205726027722315
# Angola, 1992, empratio=64.229, gdpcap=6578.068575, laborshare=0.284384667873383, whours=2100.0
# Hourly wage => 1.3869286510912315
# Angola, 1993, empratio=63.937, gdpcap=4843.155884, laborshare=0.284384667873383, whours=2100.0
# Hourly wage => 1.0258009018776377
# Angola, 1994, empratio=63.965, gdpcap=4751.471649, laborshare=0.284384667873383, whours=2100.0
# Hourly wage => 1.0059412601464794
# Angola, 1995, empratio=64.298, gdpcap=5284.703133, laborshare=0.284384667873383, whours=2100.0
# Hourly wage => 1.1130380603467127
# Angola, 1996, empratio=64.851, gdpcap=5800.962514, laborshare=0.284384667873383, whours=2100.0
# Hourly wage => 1.2113517344079099
# Angola, 1997, empratio=64.922, gdpcap=6015.186847, laborshare=0.284384667873383, whours=2100.0
# Hourly wage => 1.254712184790567
# Angola, 1998, empratio=64.754, gdpcap=6090.095878, laborshare=0.284384667873383, whours=2120.0
# Hourly wage => 1.261617912423046
# Angola, 1999, empratio=64.566, gdpcap=6021.229148, laborshare=0.284384667873383, whours=2120.0
# Hourly wage => 1.2509835273453644
# Angola, 2000, empratio=64.479, gdpcap=6002.98914, laborshare=0.284384667873383, whours=2120.0
# Hourly wage => 1.2488767535154968
# Angola, 2001, empratio=64.444, gdpcap=6049.163212, laborshare=0.284384667873383, whours=2120.0
# Hourly wage => 1.2591664131360114
# Angola, 2002, empratio=64.587, gdpcap=6645.477766, laborshare=0.284384667873383, whours=2130.0
# Hourly wage => 1.3737498936680894
# Angola, 2003, empratio=64.558, gdpcap=6609.214889, laborshare=0.291652709245682, whours=2130.0
# Hourly wage => 1.4018005197086298
# Angola, 2004, empratio=64.631, gdpcap=7074.025947, laborshare=0.275552868843079, whours=2130.0
# Hourly wage => 1.4159603957302633
# Angola, 2005, empratio=64.63, gdpcap=7845.890153, laborshare=0.231606543064117, whours=2140.0
# Hourly wage => 1.3138479826916452
# Angola, 2006, empratio=64.74, gdpcap=8435.455047, laborshare=0.237113997340202, whours=2140.0
# Hourly wage => 1.4437075877757988
# Angola, 2007, empratio=64.774, gdpcap=9263.980703, laborshare=0.242621317505837, whours=2140.0
# Hourly wage => 1.6214819113057866
# Angola, 2008, empratio=64.715, gdpcap=9916.909351, laborshare=0.255717515945435, whours=2140.0
# Hourly wage => 1.831125419863063
# Angola, 2009, empratio=64.562, gdpcap=9629.091948, laborshare=0.360010325908661, whours=2140.0
# Hourly wage => 2.5090513085038184
# Angola, 2010, empratio=64.421, gdpcap=9672.839224, laborshare=0.300494611263275, whours=2140.0
# Hourly wage => 2.108382593668691
# Angola, 2011, empratio=64.35, gdpcap=9627.020598, laborshare=0.287627995014191, whours=2140.0
# Hourly wage => 2.010762283193588
# Angola, 2012, empratio=64.278, gdpcap=10051.33991, laborshare=0.282354950904846, whours=2140.0
# Hourly wage => 2.0632090708321953
# Angola, 2013, empratio=64.098, gdpcap=10150.9161, laborshare=0.280896753072739, whours=2140.0
# Hourly wage => 2.0787090424940655
# Angola, 2014, empratio=63.927, gdpcap=10250.5924, laborshare=0.28877466917038, whours=2140.0
# Hourly wage => 2.163764355860936
# Angola, 2015, empratio=63.624, gdpcap=9980.929882, laborshare=0.349127531051636, whours=2150.0
# Hourly wage => 2.5473913656263667
# Angola, 2016, empratio=63.319, gdpcap=9381.809726, laborshare=0.343024909496307, whours=2150.0
# Hourly wage => 2.3639580846431874
# Angola, 2017, empratio=63.05, gdpcap=9042.117129, laborshare=0.346370577812195, whours=2150.0
# Hourly wage => 2.310402105834997
# Angola, 2018, empratio=62.818, gdpcap=8620.214664, laborshare=0.331142336130142, whours=2150.0
# Hourly wage => 2.113538795931152
# Angola, 2019, empratio=62.645, gdpcap=8274.542562, laborshare=0.331142336130142, whours=2150.0
# Hourly wage => 2.0343882040282137
# Angola, 2020, empratio=62.257, gdpcap=7556.967928, laborshare=0.3169910661472475, whours=2100.0
# Hourly wage => 1.8322600712234125
# Angola, 2021, empratio=64.306, gdpcap=7408.126591, laborshare=0.3187034637469961, whours=2130.0
# Hourly wage => 1.7237095147832104
# Angola, 2022, empratio=64.573, gdpcap=7397.486427, laborshare=0.3204158613467451, whours=2150.0
# Hourly wage => 1.7072957523884533
# Angola, 2023, empratio=64.739, gdpcap=7244.893053, laborshare=0.3221282589464938, whours=2150.0
# Hourly wage => 1.67670383469397
# Argentina, 1991, empratio=56.669, gdpcap=18295.6092, laborshare=0.441023617982864, whours=1838.0
# Hourly wage => 7.746716570184919
# Argentina, 1992, empratio=56.831, gdpcap=19476.28406, laborshare=0.441023617982864, whours=1826.0
# Hourly wage => 8.277170030444202
# Argentina, 1993, empratio=55.275, gdpcap=20791.34515, laborshare=0.441023617982864, whours=1850.0
# Hourly wage => 8.966933647031157
# Argentina, 1994, empratio=54.716, gdpcap=21711.84279, laborshare=0.431845158338547, whours=1875.0
# Hourly wage => 9.139219911269526
# Argentina, 1995, empratio=49.937, gdpcap=20819.49995, laborshare=0.393929451704025, whours=1882.0
# Hourly wage => 8.726632326184209
# Argentina, 1996, empratio=51.39, gdpcap=21695.59495, laborshare=0.366972714662552, whours=1889.0
# Hourly wage => 8.201527833296973
# Argentina, 1997, empratio=53.487, gdpcap=23172.15834, laborshare=0.356873691082001, whours=1896.0
# Hourly wage => 8.154445744035021
# Argentina, 1998, empratio=55.125, gdpcap=23783.10172, laborshare=0.36957648396492, whours=1903.0
# Hourly wage => 8.378869608156727
# Argentina, 1999, empratio=53.767, gdpcap=22714.51113, laborshare=0.391513794660568, whours=1887.0
# Hourly wage => 8.765218719860846
# Argentina, 2000, empratio=52.975, gdpcap=22281.38143, laborshare=0.391106188297272, whours=1862.0
# Hourly wage => 8.83458510878246
# Argentina, 2001, empratio=50.969, gdpcap=21066.45813, laborshare=0.399784564971924, whours=1811.0
# Hourly wage => 9.124161924131537
# Argentina, 2002, empratio=48.336, gdpcap=18571.70205, laborshare=0.317552953958511, whours=1710.0
# Hourly wage => 7.135116133961435
# Argentina, 2003, empratio=51.646, gdpcap=20005.13851, laborshare=0.310135722160339, whours=1714.0
# Hourly wage => 7.008835165846131
# Argentina, 2004, empratio=53.567, gdpcap=21591.4494, laborshare=0.324794858694077, whours=1743.0
# Hourly wage => 7.510973524947475
# Argentina, 2005, empratio=54.434, gdpcap=23262.40758, laborshare=0.338950276374817, whours=1772.0
# Hourly wage => 8.174415080984687
# Argentina, 2006, empratio=55.567, gdpcap=24877.24939, laborshare=0.355539232492447, whours=1776.0
# Hourly wage => 8.962516716127892
# Argentina, 2007, empratio=55.937, gdpcap=26850.66459, laborshare=0.364846795797348, whours=1788.0
# Hourly wage => 9.794874839710427
# Argentina, 2008, empratio=55.692, gdpcap=27658.48534, laborshare=0.403679102659225, whours=1790.0
# Hourly wage => 11.200020446618945
# Argentina, 2009, empratio=55.526, gdpcap=25747.19768, laborshare=0.443854510784149, whours=1752.0
# Hourly wage => 11.747355583224223
# Argentina, 2010, empratio=55.544, gdpcap=28056.25702, laborshare=0.44069242477417, whours=1760.0
# Hourly wage => 12.647814771163329
# Argentina, 2011, empratio=56.296, gdpcap=29425.75939, laborshare=0.473123997449875, whours=1760.0
# Hourly wage => 14.051168772077899
# Argentina, 2012, empratio=56.006, gdpcap=28825.96669, laborshare=0.520179331302643, whours=1736.0
# Hourly wage => 15.422426017386535
# Argentina, 2013, empratio=55.705, gdpcap=29227.66018, laborshare=0.543917655944824, whours=1726.0
# Hourly wage => 16.53454452305653
# Argentina, 2014, empratio=55.124, gdpcap=28200.81526, laborshare=0.543917655944824, whours=1705.0
# Hourly wage => 16.32035918801059
# Argentina, 2015, empratio=54.743, gdpcap=28669.20613, laborshare=0.543917655944824, whours=1703.0
# Hourly wage => 16.726519533803845
# Argentina, 2016, empratio=54.249, gdpcap=27802.10572, laborshare=0.543917655944824, whours=1647.0
# Hourly wage => 16.92487659592793
# Argentina, 2017, empratio=53.899, gdpcap=28334.90418, laborshare=0.543917655944824, whours=1649.0
# Hourly wage => 17.340177610915706
# Argentina, 2018, empratio=54.1, gdpcap=27367.11509, laborshare=0.543917655944824, whours=1638.0
# Hourly wage => 16.797746101400676
# Argentina, 2019, empratio=54.355, gdpcap=26629.55294, laborshare=0.543917655944824, whours=1609.0
# Hourly wage => 16.561569364285464
# Argentina, 2020, empratio=49.602, gdpcap=23877.09314, laborshare=0.5220673906392097, whours=1649.0
# Hourly wage => 15.240112644924277
# Argentina, 2021, empratio=55.085, gdpcap=26300.27426, laborshare=0.5280777553032205, whours=1641.0
# Hourly wage => 15.364421618287738
# Argentina, 2022, empratio=57.3, gdpcap=27627.96348, laborshare=0.5340881199672332, whours=1633.0
# Hourly wage => 15.769611143589062
# Argentina, 2023, empratio=58.462, gdpcap=27104.98, laborshare=0.540098484631244, whours=1624.0
# Hourly wage => 15.419218277065509
# Armenia, 1991, empratio=64.287, gdpcap=5326.752856, laborshare=0.74037629365921, whours=1850.0
# Hourly wage => 3.316043079420362
# Armenia, 1992, empratio=64.005, gdpcap=3136.724283, laborshare=0.719028115272522, whours=1800.0
# Hourly wage => 1.9576534379562733
# Armenia, 1993, empratio=61.278, gdpcap=2958.880372, laborshare=0.74037629365921, whours=1750.0
# Hourly wage => 2.0428537701270972
# Armenia, 1994, empratio=59.924, gdpcap=3200.896495, laborshare=0.74037629365921, whours=1700.0
# Hourly wage => 2.32634659132436
# Armenia, 1995, empratio=59.336, gdpcap=3480.755937, laborshare=0.74037629365921, whours=1680.0
# Hourly wage => 2.585226085112096
# Armenia, 1996, empratio=57.197, gdpcap=3717.335765, laborshare=0.74037629365921, whours=1680.0
# Hourly wage => 2.8641895928373735
# Armenia, 1997, empratio=55.804, gdpcap=3879.17938, laborshare=0.726956963539124, whours=1700.0
# Hourly wage => 2.9725852069516225
# Armenia, 1998, empratio=56.335, gdpcap=4211.512768, laborshare=0.745937824249268, whours=1720.0
# Hourly wage => 3.2421567315951827
# Armenia, 1999, empratio=55.005, gdpcap=4406.967067, laborshare=0.715652108192444, whours=1750.0
# Hourly wage => 3.276434892654663
# Armenia, 2000, empratio=54.923, gdpcap=4589.00825, laborshare=0.681093335151672, whours=1800.0
# Hourly wage => 3.1615402311023697
# Armenia, 2001, empratio=54.762, gdpcap=5044.116478, laborshare=0.698984146118164, whours=1820.0
# Hourly wage => 3.5375431279805705
# Armenia, 2002, empratio=54.541, gdpcap=5731.353466, laborshare=0.657670617103577, whours=1700.0
# Hourly wage => 4.0653094982220015
# Armenia, 2003, empratio=54.324, gdpcap=6569.260234, laborshare=0.641331493854523, whours=1750.0
# Hourly wage => 4.431688682077202
# Armenia, 2004, empratio=54.134, gdpcap=7299.400019, laborshare=0.637955367565155, whours=1800.0
# Hourly wage => 4.778975856338226
# Armenia, 2005, empratio=54.004, gdpcap=8362.90084, laborshare=0.602977097034454, whours=1840.0
# Hourly wage => 5.074742522383807
# Armenia, 2006, empratio=53.97, gdpcap=9525.231468, laborshare=0.59388279914856, whours=1840.0
# Hourly wage => 5.696473007099141
# Armenia, 2007, empratio=54.073, gdpcap=10898.84838, laborshare=0.587402939796448, whours=1840.0
# Hourly wage => 6.434553830618425
# Armenia, 2008, empratio=50.026, gdpcap=11727.48213, laborshare=0.565523266792297, whours=1840.0
# Hourly wage => 7.205127252748012
# Armenia, 2009, empratio=49.445, gdpcap=10143.23508, laborshare=0.579101920127869, whours=1840.0
# Hourly wage => 6.456412824895865
# Armenia, 2010, empratio=49.482, gdpcap=10438.56419, laborshare=0.568248867988586, whours=1850.0
# Hourly wage => 6.479781656221908
# Armenia, 2011, empratio=49.94, gdpcap=10990.1771, laborshare=0.591894030570984, whours=1850.0
# Hourly wage => 7.040903376384558
# Armenia, 2012, empratio=50.776, gdpcap=11796.27412, laborshare=0.581522583961487, whours=1850.0
# Hourly wage => 7.302662470224725
# Armenia, 2013, empratio=51.437, gdpcap=12194.01895, laborshare=0.585155487060547, whours=1842.0
# Hourly wage => 7.531004213510431
# Armenia, 2014, empratio=50.961, gdpcap=12667.37573, laborshare=0.579614102840424, whours=1842.0
# Hourly wage => 7.821643707279967
# Armenia, 2015, empratio=50.585, gdpcap=13112.76009, laborshare=0.573068022727966, whours=1842.0
# Hourly wage => 8.064712888823442
# Armenia, 2016, empratio=51.09, gdpcap=13192.99407, laborshare=0.564273953437805, whours=1840.0
# Hourly wage => 7.919169625597217
# Armenia, 2017, empratio=51.034, gdpcap=14243.8749, laborshare=0.548671960830689, whours=1830.0
# Hourly wage => 8.368164683535776
# Armenia, 2018, empratio=50.226, gdpcap=15037.04524, laborshare=0.548671960830689, whours=1820.0
# Hourly wage => 9.025583589571378
# Armenia, 2019, empratio=51.612, gdpcap=16215.3608, laborshare=0.548671960830689, whours=1800.0
# Hourly wage => 9.57670675824
# Armenia, 2020, empratio=51.101, gdpcap=15052.93598, laborshare=0.515675889741015, whours=1750.0
# Hourly wage => 8.680217222141069
# Armenia, 2021, empratio=53.381, gdpcap=15921.70528, laborshare=0.5074217021758862, whours=1780.0
# Hourly wage => 8.502603180486508
# Armenia, 2022, empratio=53.885, gdpcap=17886.17839, laborshare=0.4991675146107539, whours=1800.0
# Hourly wage => 9.204993363253923
# Armenia, 2023, empratio=53.816, gdpcap=19230.18993, laborshare=0.4909133270456216, whours=1800.0
# Hourly wage => 9.745507860379718
# Australia, 1991, empratio=57.218, gdpcap=35587.56324, laborshare=0.617311120033264, whours=1850.0
# Hourly wage => 20.753815443579953
# Australia, 1992, empratio=56.24, gdpcap=35342.06871, laborshare=0.607275784015656, whours=1847.0
# Hourly wage => 20.661684362824758
# Australia, 1993, empratio=55.787, gdpcap=36446.61276, laborshare=0.601339638233185, whours=1864.0
# Hourly wage => 21.07648040273988
# Australia, 1994, empratio=56.943, gdpcap=37534.09511, laborshare=0.604075372219086, whours=1870.0
# Hourly wage => 21.29291546399559
# Australia, 1995, empratio=58.283, gdpcap=38560.77734, laborshare=0.607523500919342, whours=1870.0
# Hourly wage => 21.49440155384926
# Australia, 1996, empratio=58.233, gdpcap=39567.50397, laborshare=0.617958426475525, whours=1864.0
# Hourly wage => 22.52593574332151
# Australia, 1997, empratio=57.967, gdpcap=40673.38633, laborshare=0.611847579479218, whours=1861.0
# Hourly wage => 23.068873114454032
# Australia, 1998, empratio=58.281, gdpcap=42147.87053, laborshare=0.613369345664978, whours=1847.0
# Hourly wage => 24.01617361421911
# Australia, 1999, empratio=58.582, gdpcap=43785.30205, laborshare=0.605032026767731, whours=1848.0
# Hourly wage => 24.47037094445776
# Australia, 2000, empratio=59.303, gdpcap=44984.55063, laborshare=0.60654604434967, whours=1847.0
# Hourly wage => 24.910566377627976
# Australia, 2001, empratio=59.164, gdpcap=45310.0182, laborshare=0.608154714107513, whours=1814.0
# Hourly wage => 25.67518035810836
# Australia, 2002, empratio=59.459, gdpcap=46580.27533, laborshare=0.600817263126373, whours=1808.0
# Hourly wage => 26.033252276242692
# Australia, 2003, empratio=59.935, gdpcap=47470.80288, laborshare=0.60151207447052, whours=1802.0
# Hourly wage => 26.438428087262807
# Australia, 2004, empratio=60.144, gdpcap=48949.92517, laborshare=0.603244006633759, whours=1799.0
# Hourly wage => 27.291133652749696
# Australia, 2005, empratio=61.26, gdpcap=49882.95635, laborshare=0.593034625053406, whours=1797.0
# Hourly wage => 26.872443948440264
# Australia, 2006, empratio=61.747, gdpcap=50570.35709, laborshare=0.588050246238709, whours=1787.0
# Hourly wage => 26.950699511002522
# Australia, 2007, empratio=62.415, gdpcap=51529.49405, laborshare=0.593336462974548, whours=1786.0
# Hourly wage => 27.427516641889422
# Australia, 2008, empratio=62.783, gdpcap=52318.48794, laborshare=0.569114029407501, whours=1786.0
# Hourly wage => 26.554061515430046
# Australia, 2009, empratio=61.856, gdpcap=52221.28512, laborshare=0.577103137969971, whours=1758.0
# Hourly wage => 27.71406861771411
# Australia, 2010, empratio=62.066, gdpcap=52556.56848, laborshare=0.574954748153687, whours=1763.0
# Hourly wage => 27.61560721826192
# Australia, 2011, empratio=62.184, gdpcap=53078.95265, laborshare=0.575421273708344, whours=1765.0
# Hourly wage => 27.82818580348395
# Australia, 2012, empratio=61.836, gdpcap=54203.30038, laborshare=0.582465291023254, whours=1757.0
# Hourly wage => 29.059131618073696
# Australia, 2013, empratio=61.343, gdpcap=54664.76814, laborshare=0.582097172737122, whours=1756.0
# Hourly wage => 29.540203121854
# Australia, 2014, empratio=60.849, gdpcap=55253.15962, laborshare=0.596026003360748, whours=1746.0
# Hourly wage => 30.9973552556658
# Australia, 2015, empratio=61.135, gdpcap=55656.48796, laborshare=0.604028284549713, whours=1746.0
# Hourly wage => 31.494804558162464
# Australia, 2016, empratio=61.242, gdpcap=56305.89643, laborshare=0.583876967430115, whours=1736.0
# Hourly wage => 30.92260941218631
# Australia, 2017, empratio=61.599, gdpcap=56648.80866, laborshare=0.579755961894989, whours=1737.0
# Hourly wage => 30.694638577443175
# Australia, 2018, empratio=62.232, gdpcap=57414.05823, laborshare=0.571645140647888, whours=1729.0
# Hourly wage => 30.502540310600267
# Australia, 2019, empratio=62.607, gdpcap=57800.4934, laborshare=0.571645140647888, whours=1727.0
# Hourly wage => 30.559259783299925
# Australia, 2020, empratio=60.901, gdpcap=57023.66782, laborshare=0.5736681296320381, whours=1717.0
# Hourly wage => 31.283918965631425
# Australia, 2021, empratio=62.591, gdpcap=58145.55136, laborshare=0.572260806360855, whours=1711.0
# Hourly wage => 31.070525296531297
# Australia, 2022, empratio=64.216, gdpcap=59845.7858, laborshare=0.5708534830896719, whours=1706.0
# Hourly wage => 31.184296587974067
# Australia, 2023, empratio=64.334, gdpcap=60408.94337, laborshare=0.5694461598184892, whours=1700.0
# Hourly wage => 31.45317069625528
# Austria, 1991, empratio=54.168, gdpcap=44316.44481, laborshare=0.632960438728333, whours=1836.0
# Hourly wage => 28.204993355032908
# Austria, 1992, empratio=54.896, gdpcap=44749.01434, laborshare=0.632960438728333, whours=1805.0
# Hourly wage => 28.585259126405393
# Austria, 1993, empratio=54.759, gdpcap=44615.3248, laborshare=0.632960438728333, whours=1802.0
# Hourly wage => 28.618728225940117
# Austria, 1994, empratio=56.619, gdpcap=45511.54031, laborshare=0.632960438728333, whours=1801.0
# Hourly wage => 28.250243358170746
# Austria, 1995, empratio=56.326, gdpcap=46654.29531, laborshare=0.632960438728333, whours=1774.0
# Hourly wage => 29.553279033000482
# Austria, 1996, empratio=55.309, gdpcap=47623.70112, laborshare=0.621577680110931, whours=1807.0
# Hourly wage => 29.618604749638
# Austria, 1997, empratio=55.097, gdpcap=48590.53469, laborshare=0.611112892627716, whours=1816.0
# Hourly wage => 29.67763762165597
# Austria, 1998, empratio=55.202, gdpcap=50232.59424, laborshare=0.607895135879517, whours=1794.0
# Hourly wage => 30.83450810163787
# Austria, 1999, empratio=55.823, gdpcap=52020.99428, laborshare=0.607916057109833, whours=1798.0
# Hourly wage => 31.507896023767056
# Austria, 2000, empratio=55.69, gdpcap=53551.28775, laborshare=0.596380054950714, whours=1798.0
# Hourly wage => 31.895258344576817
# Austria, 2001, empratio=55.572, gdpcap=54049.25484, laborshare=0.588483393192291, whours=1785.0
# Hourly wage => 32.06488414329331
# Austria, 2002, empratio=55.843, gdpcap=54582.34906, laborshare=0.584004878997803, whours=1783.0
# Hourly wage => 32.01463930991887
# Austria, 2003, empratio=55.921, gdpcap=54937.17159, laborshare=0.583080470561981, whours=1774.0
# Hourly wage => 32.28986634132329
# Austria, 2004, empratio=54.203, gdpcap=55997.95159, laborshare=0.572628557682037, whours=1776.0
# Hourly wage => 33.31032408129631
# Austria, 2005, empratio=54.765, gdpcap=56908.28746, laborshare=0.563615024089813, whours=1752.0
# Hourly wage => 33.42880748636443
# Austria, 2006, empratio=55.447, gdpcap=58478.7421, laborshare=0.556628346443176, whours=1736.0
# Hourly wage => 33.81703813015604
# Austria, 2007, empratio=56.506, gdpcap=60490.05143, laborshare=0.550686657428742, whours=1725.0
# Hourly wage => 34.17471042416365
# Austria, 2008, empratio=57.154, gdpcap=61177.34622, laborshare=0.562085688114166, whours=1717.0
# Hourly wage => 35.04097936043283
# Austria, 2009, empratio=56.703, gdpcap=58829.05799, laborshare=0.579667806625366, whours=1673.0
# Hourly wage => 35.94753355681273
# Austria, 2010, empratio=56.953, gdpcap=59749.45838, laborshare=0.576476156711578, whours=1666.0
# Hourly wage => 36.301428863471145
# Austria, 2011, empratio=57.131, gdpcap=61291.65357, laborshare=0.571340143680573, whours=1672.0
# Hourly wage => 36.659621689043234
# Austria, 2012, empratio=57.252, gdpcap=61396.14888, laborshare=0.579930365085602, whours=1648.0
# Hourly wage => 37.73715099242344
# Austria, 2013, empratio=57.122, gdpcap=60882.32026, laborshare=0.584707736968994, whours=1632.0
# Hourly wage => 38.18620296171016
# Austria, 2014, empratio=56.758, gdpcap=60864.9199, laborshare=0.58194237947464, whours=1622.0
# Hourly wage => 38.47415645729966
# Austria, 2015, empratio=56.73, gdpcap=60970.9828, laborshare=0.578767776489258, whours=1605.0
# Hourly wage => 38.75606883073596
# Austria, 2016, empratio=57.015, gdpcap=61592.20228, laborshare=0.579816699028015, whours=1618.0
# Hourly wage => 38.71228497418531
# Austria, 2017, empratio=57.292, gdpcap=62555.69347, laborshare=0.58076423406601, whours=1608.0
# Hourly wage => 39.43543883920811
# Austria, 2018, empratio=57.914, gdpcap=63798.21387, laborshare=0.583859503269196, whours=1613.0
# Hourly wage => 39.87483917203197
# Austria, 2019, empratio=58.121, gdpcap=64629.82578, laborshare=0.583859503269196, whours=1611.0
# Hourly wage => 40.30071212476033
# Austria, 2020, empratio=57.224, gdpcap=60295.49515, laborshare=0.5593575444714762, whours=1595.0
# Hourly wage => 36.95178876850212
# Austria, 2021, empratio=56.715, gdpcap=62912.17411, laborshare=0.5572180949408425, whours=1586.0
# Hourly wage => 38.97254664081763
# Austria, 2022, empratio=57.843, gdpcap=65602.25653, laborshare=0.5550786454102079, whours=1577.0
# Hourly wage => 39.92002413912403
# Austria, 2023, empratio=57.649, gdpcap=64336.03753, laborshare=0.5529391958795733, whours=1569.0
# Hourly wage => 39.329367660272545
# Azerbaijan, 1991, empratio=71.257, gdpcap=10399.39312, laborshare=0.569162964820862, whours=1880.0
# Hourly wage => 4.418341147310107
# Azerbaijan, 1992, empratio=72.353, gdpcap=7928.372295, laborshare=0.569162964820862, whours=1860.0
# Hourly wage => 3.3531360966564785
# Azerbaijan, 1993, empratio=72.414, gdpcap=6005.197797, laborshare=0.569162964820862, whours=1840.0
# Hourly wage => 2.565213925781398
# Azerbaijan, 1994, empratio=72.997, gdpcap=4757.584413, laborshare=0.569162964820862, whours=1820.0
# Hourly wage => 2.0381997106674716
# Azerbaijan, 1995, empratio=73.541, gdpcap=4147.974691, laborshare=0.513965487480164, whours=1800.0
# Hourly wage => 1.6105270333821329
# Azerbaijan, 1996, empratio=72.846, gdpcap=4159.597892, laborshare=0.483230710029602, whours=1780.0
# Hourly wage => 1.5501729852053565
# Azerbaijan, 1997, empratio=71.718, gdpcap=4358.6048, laborshare=0.428940892219543, whours=1760.0
# Hourly wage => 1.4811672673022864
# Azerbaijan, 1998, empratio=70.371, gdpcap=4749.174441, laborshare=0.389421045780182, whours=1740.0
# Hourly wage => 1.510409017271459
# Azerbaijan, 1999, empratio=69.223, gdpcap=5056.04634, laborshare=0.408844590187073, whours=1720.0
# Hourly wage => 1.736162763690377
# Azerbaijan, 2000, empratio=67.753, gdpcap=5571.309502, laborshare=0.401025891304016, whours=1700.0
# Hourly wage => 1.939778971167835
# Azerbaijan, 2001, empratio=66.459, gdpcap=6075.614524, laborshare=0.377947062253952, whours=1680.0
# Hourly wage => 2.0566391637927532
# Azerbaijan, 2002, empratio=65.205, gdpcap=6599.657606, laborshare=0.37708979845047, whours=1650.0
# Hourly wage => 2.313136942452964
# Azerbaijan, 2003, empratio=64.066, gdpcap=7218.471886, laborshare=0.379396855831146, whours=1650.0
# Hourly wage => 2.5907615512543622
# Azerbaijan, 2004, empratio=62.538, gdpcap=7817.716107, laborshare=0.385607898235321, whours=1680.0
# Hourly wage => 2.8692774574208273
# Azerbaijan, 2005, empratio=61.711, gdpcap=9901.92663, laborshare=0.341989487409592, whours=1700.0
# Hourly wage => 3.227906563098284
# Azerbaijan, 2006, empratio=60.511, gdpcap=13172.58129, laborshare=0.255406320095062, whours=1720.0
# Hourly wage => 3.232509055082397
# Azerbaijan, 2007, empratio=57.876, gdpcap=16280.08351, laborshare=0.231887400150299, whours=1740.0
# Hourly wage => 3.748746070040005
# Azerbaijan, 2008, empratio=57.259, gdpcap=17656.96345, laborshare=0.211646258831024, whours=1760.0
# Hourly wage => 3.7082600914153927
# Azerbaijan, 2009, empratio=57.482, gdpcap=18901.88576, laborshare=0.254765182733536, whours=1780.0
# Hourly wage => 4.706448779524946
# Azerbaijan, 2010, empratio=57.437, gdpcap=19621.38435, laborshare=0.231420874595642, whours=1800.0
# Hourly wage => 4.3920565402617395
# Azerbaijan, 2011, empratio=57.873, gdpcap=19386.7434, laborshare=0.212007343769074, whours=1800.0
# Hourly wage => 3.945547407989743
# Azerbaijan, 2012, empratio=58.398, gdpcap=19545.07186, laborshare=0.229080632328987, whours=1800.0
# Hourly wage => 4.259466097206801
# Azerbaijan, 2013, empratio=58.82, gdpcap=20414.83148, laborshare=0.242707118391991, whours=1800.0
# Hourly wage => 4.679837660063568
# Azerbaijan, 2014, empratio=59.68, gdpcap=20716.14152, laborshare=0.250552535057068, whours=1800.0
# Hourly wage => 4.831771088804161
# Azerbaijan, 2015, empratio=60.386, gdpcap=20694.77876, laborshare=0.288774907588959, whours=1800.0
# Hourly wage => 5.498085303062291
# Azerbaijan, 2016, empratio=61.419, gdpcap=19830.32232, laborshare=0.272133499383926, whours=1800.0
# Hourly wage => 4.881311616250468
# Azerbaijan, 2017, empratio=61.787, gdpcap=19675.95989, laborshare=0.254187077283859, whours=1800.0
# Hourly wage => 4.496967842204795
# Azerbaijan, 2018, empratio=62.195, gdpcap=19798.83354, laborshare=0.254187077283859, whours=1800.0
# Hourly wage => 4.495366393477717
# Azerbaijan, 2019, empratio=61.957, gdpcap=20122.71285, laborshare=0.254187077283859, whours=1800.0
# Hourly wage => 4.5864547332682815
# Azerbaijan, 2020, empratio=62.356, gdpcap=19126.0949, laborshare=0.1601966705007953, whours=1750.0
# Hourly wage => 2.8077827063609333
# Azerbaijan, 2021, empratio=58.411, gdpcap=20111.3757, laborshare=0.147411954549721, whours=1780.0
# Hourly wage => 2.8514111265989834
# Azerbaijan, 2022, empratio=60.401, gdpcap=21051.26876, laborshare=0.1346272385986431, whours=1800.0
# Hourly wage => 2.606721174738351
# Azerbaijan, 2023, empratio=59.956, gdpcap=21262.298, laborshare=0.1218425226475687, whours=1800.0
# Hourly wage => 2.4005122512104755
# Burundi, 1991, empratio=86.724, gdpcap=1435.819561, laborshare=0.733962833881378, whours=2100.0
# Hourly wage => 0.5786491760032791
# Burundi, 1992, empratio=86.206, gdpcap=1412.060546, laborshare=0.741343975067139, whours=2100.0
# Hourly wage => 0.5782508665329419
# Burundi, 1993, empratio=85.534, gdpcap=1366.292153, laborshare=0.748725056648254, whours=2100.0
# Hourly wage => 0.569518537130314
# Burundi, 1994, empratio=84.795, gdpcap=1305.45208, laborshare=0.756106197834015, whours=2100.0
# Hourly wage => 0.5543118887082327
# Burundi, 1995, empratio=84.207, gdpcap=1132.218782, laborshare=0.763487339019775, whours=2100.0
# Hourly wage => 0.4888377140105368
# Burundi, 1996, empratio=83.408, gdpcap=1040.922315, laborshare=0.770868480205536, whours=2100.0
# Hourly wage => 0.45811193340828227
# Burundi, 1997, empratio=82.485, gdpcap=1024.449954, laborshare=0.778249621391296, whours=2100.0
# Hourly wage => 0.46027288588391574
# Burundi, 1998, empratio=81.557, gdpcap=1052.807034, laborshare=0.785630762577057, whours=2100.0
# Hourly wage => 0.48293282055606424
# Burundi, 1999, empratio=80.841, gdpcap=1017.497778, laborshare=0.793011903762817, whours=2100.0
# Hourly wage => 0.47529386020307723
# Burundi, 2000, empratio=80.069, gdpcap=988.0368635, laborshare=0.800393044948578, whours=2100.0
# Hourly wage => 0.470319250657146
# Burundi, 2001, empratio=79.279, gdpcap=983.3968467, laborshare=0.807774126529694, whours=2100.0
# Hourly wage => 0.47713501796557417
# Burundi, 2002, empratio=78.474, gdpcap=998.561289, laborshare=0.815155267715454, whours=2100.0
# Hourly wage => 0.4939352038133855
# Burundi, 2003, empratio=77.687, gdpcap=955.6692044, laborshare=0.822536408901215, whours=2100.0
# Hourly wage => 0.48183137552869804
# Burundi, 2004, empratio=76.826, gdpcap=965.2041181, laborshare=0.829917550086975, whours=2100.0
# Hourly wage => 0.4965083974717211
# Burundi, 2005, empratio=75.956, gdpcap=938.3815973, laborshare=0.837298691272736, whours=2100.0
# Hourly wage => 0.49258197310580154
# Burundi, 2006, empratio=74.981, gdpcap=954.1908539, laborshare=0.618850827217102, whours=2080.0
# Hourly wage => 0.37862271215054477
# Burundi, 2007, empratio=75.812, gdpcap=951.2900826, laborshare=0.614920377731323, whours=2080.0
# Hourly wage => 0.37096297478558643
# Burundi, 2008, empratio=76.607, gdpcap=957.2226644, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.3641750318375821
# Burundi, 2009, empratio=76.892, gdpcap=944.6299256, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.358052072365752
# Burundi, 2010, empratio=77.155, gdpcap=947.6214173, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.35796160058396753
# Burundi, 2011, empratio=77.307, gdpcap=951.1884604, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.35860257343725094
# Burundi, 2012, empratio=77.448, gdpcap=958.6574029, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.3607604104768666
# Burundi, 2013, empratio=77.59, gdpcap=970.3753918, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.3645017954259403
# Burundi, 2014, empratio=77.697, gdpcap=977.7658403, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.3667720724995084
# Burundi, 2015, empratio=78.374, gdpcap=918.5571929, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.3415858240302015
# Burundi, 2016, empratio=78.899, gdpcap=897.4590464, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.33151927961308575
# Burundi, 2017, empratio=79.156, gdpcap=880.9934401, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.3243803096434858
# Burundi, 2018, empratio=79.189, gdpcap=868.5555076, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.3196674149267285
# Burundi, 2019, empratio=78.966, gdpcap=855.7327201, laborshare=0.606218218803406, whours=2080.0
# Hourly wage => 0.31583746689837283
# Burundi, 2020, empratio=77.738, gdpcap=833.9202575, laborshare=0.5760473653013456, whours=2050.0
# Hourly wage => 0.30143626101451143
# Burundi, 2021, empratio=78.255, gdpcap=836.6655713, laborshare=0.5678002905963062, whours=2070.0
# Hourly wage => 0.2932682633395434
# Burundi, 2022, empratio=78.436, gdpcap=829.3871596, laborshare=0.5595532158912668, whours=2080.0
# Hourly wage => 0.2844591648783619
# Burundi, 2023, empratio=78.185, gdpcap=828.8610743, laborshare=0.5513061411862274, whours=2080.0
# Hourly wage => 0.28098801686569574
# Belgium, 1991, empratio=45.757, gdpcap=42226.53354, laborshare=0.632270753383637, whours=1619.0
# Hourly wage => 36.03994608697291
# Belgium, 1992, empratio=46.204, gdpcap=42699.28725, laborshare=0.629504323005676, whours=1596.0
# Hourly wage => 36.4507845575112
# Belgium, 1993, empratio=45.616, gdpcap=42123.70108, laborshare=0.634596765041351, whours=1552.0
# Hourly wage => 37.75856313096313
# Belgium, 1994, empratio=45.384, gdpcap=43349.21383, laborshare=0.62539678812027, whours=1552.0
# Hourly wage => 38.48951021276628
# Belgium, 1995, empratio=45.73, gdpcap=44290.13025, laborshare=0.617202520370483, whours=1578.0
# Hourly wage => 37.88143724771946
# Belgium, 1996, empratio=45.62, gdpcap=44787.79652, laborshare=0.6217400431633, whours=1552.0
# Hourly wage => 39.32978185652587
# Belgium, 1997, empratio=45.969, gdpcap=46374.5399, laborshare=0.619153320789337, whours=1565.0
# Hourly wage => 39.911534185265445
# Belgium, 1998, empratio=46.014, gdpcap=47183.47318, laborshare=0.616947174072266, whours=1576.0
# Hourly wage => 40.14132318992348
# Belgium, 1999, empratio=47.384, gdpcap=48743.20839, laborshare=0.624352931976318, whours=1575.0
# Hourly wage => 40.778569783423194
# Belgium, 2000, empratio=48.802, gdpcap=50432.39369, laborshare=0.616643667221069, whours=1589.0
# Hourly wage => 40.10350579073893
# Belgium, 2001, empratio=47.654, gdpcap=50811.88115, laborshare=0.627343952655792, whours=1581.0
# Hourly wage => 42.309681797473615
# Belgium, 2002, empratio=47.57, gdpcap=51448.0429, laborshare=0.631530225276947, whours=1594.0
# Hourly wage => 42.84908289770557
# Belgium, 2003, empratio=47.319, gdpcap=51764.88702, laborshare=0.624384045600891, whours=1598.0
# Hourly wage => 42.743958035654856
# Belgium, 2004, empratio=48.182, gdpcap=53381.98657, laborshare=0.609806954860687, whours=1588.0
# Hourly wage => 42.545318922816726
# Belgium, 2005, empratio=48.797, gdpcap=54321.75322, laborshare=0.602968096733093, whours=1578.0
# Hourly wage => 42.53711101558267
# Belgium, 2006, empratio=48.73, gdpcap=55342.01026, laborshare=0.603291273117065, whours=1592.0
# Hourly wage => 43.03705041033853
# Belgium, 2007, empratio=49.654, gdpcap=56957.10138, laborshare=0.60006719827652, whours=1594.0
# Hourly wage => 43.182244275996304
# Belgium, 2008, empratio=49.949, gdpcap=56761.46722, laborshare=0.618209302425385, whours=1583.0
# Hourly wage => 44.3794009810633
# Belgium, 2009, empratio=49.282, gdpcap=55233.1451, laborshare=0.630932033061981, whours=1563.0
# Hourly wage => 45.24129718412241
# Belgium, 2010, empratio=49.67, gdpcap=56214.18702, laborshare=0.613814055919647, whours=1574.0
# Hourly wage => 44.135075660697034
# Belgium, 2011, empratio=49.491, gdpcap=56559.12676, laborshare=0.618337213993073, whours=1590.0
# Hourly wage => 44.44313916507717
# Belgium, 2012, empratio=49.306, gdpcap=56330.75512, laborshare=0.623317241668701, whours=1587.0
# Hourly wage => 44.872267402374774
# Belgium, 2013, empratio=49.1, gdpcap=56237.14854, laborshare=0.62487530708313, whours=1586.0
# Hourly wage => 45.12653418970485
# Belgium, 2014, empratio=49.008, gdpcap=56976.54029, laborshare=0.617005169391632, whours=1582.0
# Hourly wage => 45.3431219426037
# Belgium, 2015, empratio=48.842, gdpcap=57482.42155, laborshare=0.601801156997681, whours=1575.0
# Hourly wage => 44.969087619513566
# Belgium, 2016, empratio=49.001, gdpcap=57874.71307, laborshare=0.593992829322815, whours=1574.0
# Hourly wage => 44.57182143794047
# Belgium, 2017, empratio=49.555, gdpcap=58502.25527, laborshare=0.593288838863373, whours=1578.0
# Hourly wage => 44.38582612120746
# Belgium, 2018, empratio=50.48, gdpcap=59330.23153, laborshare=0.594810962677002, whours=1583.0
# Hourly wage => 44.16261142834064
# Belgium, 2019, empratio=51.005, gdpcap=60451.99969, laborshare=0.594810962677002, whours=1586.0
# Hourly wage => 44.45019809441663
# Belgium, 2020, empratio=50.422, gdpcap=57307.02062, laborshare=0.6007684071369357, whours=1578.0
# Hourly wage => 43.270095068899764
# Belgium, 2021, empratio=50.671, gdpcap=60611.52714, laborshare=0.5997566570202117, whours=1577.0
# Hourly wage => 45.492429946961785
# Belgium, 2022, empratio=51.536, gdpcap=62668.95397, laborshare=0.5987449069034874, whours=1577.0
# Hourly wage => 46.16914980610679
# Belgium, 2023, empratio=51.39, gdpcap=62876.23877, laborshare=0.5977331567867634, whours=1577.0
# Hourly wage => 46.374964554651925
# Benin, 1991, empratio=70.976, gdpcap=2230.460547, laborshare=0.649636387825012, whours=2150.0
# Hourly wage => 0.9495435947816495
# Benin, 1992, empratio=71.07, gdpcap=2226.56666, laborshare=0.649636387825012, whours=2150.0
# Hourly wage => 0.9466321918148185
# Benin, 1993, empratio=71.041, gdpcap=2254.245654, laborshare=0.649636387825012, whours=2150.0
# Hourly wage => 0.9587912410454048
# Benin, 1994, empratio=71.03, gdpcap=2215.366168, laborshare=0.649636387825012, whours=2150.0
# Hourly wage => 0.9424006725551656
# Benin, 1995, empratio=71.097, gdpcap=2300.141221, laborshare=0.610204041004181, whours=2150.0
# Hourly wage => 0.9182054048886967
# Benin, 1996, empratio=71.099, gdpcap=2337.630308, laborshare=0.603259801864624, whours=2150.0
# Hourly wage => 0.9225252547867712
# Benin, 1997, empratio=71.164, gdpcap=2399.785931, laborshare=0.606281578540802, whours=2150.0
# Hourly wage => 0.9509289400354556
# Benin, 1998, empratio=71.161, gdpcap=2419.100143, laborshare=0.614448189735413, whours=2150.0
# Hourly wage => 0.9715353645533101
# Benin, 1999, empratio=71.191, gdpcap=2470.685044, laborshare=0.617155015468597, whours=2150.0
# Hourly wage => 0.9962035745620125
# Benin, 2000, empratio=71.212, gdpcap=2536.168859, laborshare=0.617155015468597, whours=2130.0
# Hourly wage => 1.031904821790545
# Benin, 2001, empratio=71.242, gdpcap=2591.064852, laborshare=0.617155015468597, whours=2130.0
# Hourly wage => 1.0537967124790406
# Benin, 2002, empratio=71.255, gdpcap=2630.18061, laborshare=0.617155015468597, whours=2130.0
# Hourly wage => 1.0695100912445672
# Benin, 2003, empratio=71.228, gdpcap=2639.043701, laborshare=0.617155015468597, whours=2130.0
# Hourly wage => 1.0735208684569097
# Benin, 2004, empratio=71.212, gdpcap=2672.844044, laborshare=0.617155015468597, whours=2130.0
# Hourly wage => 1.087514597898365
# Benin, 2005, empratio=71.176, gdpcap=2632.472515, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.0766850176571876
# Benin, 2006, empratio=71.17, gdpcap=2652.21842, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.0848525719849615
# Benin, 2007, empratio=71.174, gdpcap=2729.137414, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.1162524653593402
# Benin, 2008, empratio=71.195, gdpcap=2777.61974, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.1357472591259326
# Benin, 2009, empratio=71.17, gdpcap=2758.072432, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.1281506639924543
# Benin, 2010, empratio=71.118, gdpcap=2733.573996, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.118947477263362
# Benin, 2011, empratio=69.977, gdpcap=2732.012496, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.136542717289913
# Benin, 2012, empratio=70.556, gdpcap=2779.726481, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.146902540267776
# Benin, 2013, empratio=71.181, gdpcap=2893.046702, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.183177115928079
# Benin, 2014, empratio=71.746, gdpcap=2987.382363, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.2121364786149929
# Benin, 2015, empratio=72.18, gdpcap=2952.002183, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.190578946313917
# Benin, 2016, empratio=72.6, gdpcap=2962.663816, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.1879663919588679
# Benin, 2017, empratio=73.082, gdpcap=3041.7793, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.2116457908379206
# Benin, 2018, empratio=73.653, gdpcap=3155.451065, laborshare=0.617155015468597, whours=2120.0
# Hourly wage => 1.2471807824698091
# Benin, 2019, empratio=74.183, gdpcap=3281.104701, laborshare=0.617155015468597, whours=2101.0
# Hourly wage => 1.2992236184537618
# Benin, 2020, empratio=73.668, gdpcap=3317.859722, laborshare=0.6106680364444323, whours=2100.0
# Hourly wage => 1.3096795155820127
# Benin, 2021, empratio=74.635, gdpcap=3464.288629, laborshare=0.6100160331561633, whours=2100.0
# Hourly wage => 1.3483215822849508
# Benin, 2022, empratio=74.507, gdpcap=3588.335259, laborshare=0.6093640298678942, whours=2100.0
# Hourly wage => 1.3975052736759752
# Benin, 2023, empratio=74.339, gdpcap=3721.224527, laborshare=0.6087120265796251, whours=2100.0
# Hourly wage => 1.4509810739527076
# Burkina Faso, 1991, empratio=81.851, gdpcap=1178.077046, laborshare=0.520249605178833, whours=2400.0
# Hourly wage => 0.31199685915654973
# Burkina Faso, 1992, empratio=81.224, gdpcap=1152.044761, laborshare=0.523195624351502, whours=2380.0
# Hourly wage => 0.3117971392796681
# Burkina Faso, 1993, empratio=80.667, gdpcap=1162.649235, laborshare=0.526141703128815, whours=2360.0
# Hourly wage => 0.3213242685740656
# Burkina Faso, 1994, empratio=79.914, gdpcap=1148.607214, laborshare=0.529087781906128, whours=2340.0
# Hourly wage => 0.32498292669782275
# Burkina Faso, 1995, empratio=79.299, gdpcap=1183.52861, laborshare=0.532033860683441, whours=2320.0
# Hourly wage => 0.34226488028483565
# Burkina Faso, 1996, empratio=78.693, gdpcap=1280.696085, laborshare=0.534979939460754, whours=2300.0
# Hourly wage => 0.3785468538005561
# Burkina Faso, 1997, empratio=78.028, gdpcap=1326.942308, laborshare=0.537925958633423, whours=2280.0
# Hourly wage => 0.4012261416516623
# Burkina Faso, 1998, empratio=77.298, gdpcap=1385.093107, laborshare=0.540872037410736, whours=2260.0
# Hourly wage => 0.42884149470641747
# Burkina Faso, 1999, empratio=76.483, gdpcap=1444.566902, laborshare=0.543818116188049, whours=2240.0
# Hourly wage => 0.4585412370776874
# Burkina Faso, 2000, empratio=75.634, gdpcap=1428.574006, laborshare=0.528272032737732, whours=2220.0
# Hourly wage => 0.44945924628605294
# Burkina Faso, 2001, empratio=74.821, gdpcap=1477.284918, laborshare=0.527124524116516, whours=2200.0
# Hourly wage => 0.47307641473119266
# Burkina Faso, 2002, empratio=73.953, gdpcap=1494.678013, laborshare=0.542445182800293, whours=2200.0
# Hourly wage => 0.49833917118696003
# Burkina Faso, 2003, empratio=73.205, gdpcap=1561.833102, laborshare=0.514073967933655, whours=2200.0
# Hourly wage => 0.4985363269990679
# Burkina Faso, 2004, empratio=71.868, gdpcap=1581.256209, laborshare=0.495177656412125, whours=2200.0
# Hourly wage => 0.4952278316811511
# Burkina Faso, 2005, empratio=70.648, gdpcap=1664.995432, laborshare=0.534475922584534, whours=2200.0
# Hourly wage => 0.5725568822750144
# Burkina Faso, 2006, empratio=70.043, gdpcap=1714.760349, laborshare=0.504200339317322, whours=2200.0
# Hourly wage => 0.5610727110578109
# Burkina Faso, 2007, empratio=69.503, gdpcap=1731.930463, laborshare=0.460064738988876, whours=2200.0
# Hourly wage => 0.521102513826727
# Burkina Faso, 2008, empratio=68.542, gdpcap=1779.327109, laborshare=0.509588003158569, whours=2200.0
# Hourly wage => 0.6013059997992071
# Burkina Faso, 2009, empratio=67.557, gdpcap=1779.323056, laborshare=0.469325482845306, whours=2200.0
# Hourly wage => 0.5618700790006186
# Burkina Faso, 2010, empratio=66.702, gdpcap=1873.971462, laborshare=0.472821325063705, whours=2200.0
# Hourly wage => 0.6038074841659433
# Burkina Faso, 2011, empratio=65.77, gdpcap=1939.8666, laborshare=0.457031190395355, whours=2200.0
# Hourly wage => 0.6127272322322903
# Burkina Faso, 2012, empratio=64.877, gdpcap=2003.664612, laborshare=0.468167841434479, whours=2200.0
# Hourly wage => 0.6572236248163958
# Burkina Faso, 2013, empratio=63.859, gdpcap=2057.063932, laborshare=0.481261253356934, whours=2200.0
# Hourly wage => 0.7046669339337538
# Burkina Faso, 2014, empratio=62.834, gdpcap=2083.198447, laborshare=0.484082698822022, whours=2200.0
# Hourly wage => 0.7295126309768633
# Burkina Faso, 2015, empratio=60.542, gdpcap=2101.702662, laborshare=0.481170535087585, whours=2200.0
# Hourly wage => 0.7592605842897505
# Burkina Faso, 2016, empratio=58.3, gdpcap=2162.72579, laborshare=0.464038789272308, whours=2200.0
# Hourly wage => 0.7824642578509245
# Burkina Faso, 2017, empratio=56.089, gdpcap=2232.287815, laborshare=0.460928022861481, whours=2200.0
# Hourly wage => 0.8338403811359264
# Burkina Faso, 2018, empratio=53.889, gdpcap=2316.394321, laborshare=0.460928022861481, whours=2200.0
# Hourly wage => 0.9005810382504211
# Burkina Faso, 2019, empratio=51.692, gdpcap=2391.536268, laborshare=0.460928022861481, whours=2408.0
# Hourly wage => 0.8855850282348683
# Burkina Faso, 2020, empratio=48.931, gdpcap=2380.931718, laborshare=0.4557152914589837, whours=2300.0
# Hourly wage => 0.9641145000211556
# Burkina Faso, 2021, empratio=47.127, gdpcap=2486.430931, laborshare=0.4526149081772761, whours=2300.0
# Hourly wage => 1.0382635888812046
# Burkina Faso, 2022, empratio=44.896, gdpcap=2466.053314, laborshare=0.4495145248955685, whours=2300.0
# Hourly wage => 1.0735213980618512
# Burkina Faso, 2023, empratio=44.87, gdpcap=2482.072253, laborshare=0.4464141416138609, whours=2300.0
# Hourly wage => 1.0736641643458658
# Bulgaria, 1991, empratio=47.49, gdpcap=13815.7867, laborshare=0.409343987703323, whours=1880.0
# Hourly wage => 6.334378593742616
# Bulgaria, 1992, empratio=45.172, gdpcap=12949.36226, laborshare=0.409343987703323, whours=1850.0
# Hourly wage => 6.343015148972116
# Bulgaria, 1993, empratio=44.085, gdpcap=12859.85451, laborshare=0.409343987703323, whours=1800.0
# Hourly wage => 6.633780860721034
# Bulgaria, 1994, empratio=45.568, gdpcap=13138.18791, laborshare=0.409343987703323, whours=1750.0
# Hourly wage => 6.7441290006458
# Bulgaria, 1995, empratio=46.055, gdpcap=13574.53167, laborshare=0.409343987703323, whours=1711.0
# Hourly wage => 7.051580610207116
# Bulgaria, 1996, empratio=44.942, gdpcap=14354.98164, laborshare=0.386349529027939, whours=1708.0
# Hourly wage => 7.225081773128342
# Bulgaria, 1997, empratio=44.051, gdpcap=12404.00723, laborshare=0.500328540802002, whours=1707.0
# Hourly wage => 8.253306912824579
# Bulgaria, 1998, empratio=44.428, gdpcap=12960.20586, laborshare=0.46794918179512, whours=1650.0
# Hourly wage => 8.273130687558924
# Bulgaria, 1999, empratio=43.239, gdpcap=11938.80256, laborshare=0.536036193370819, whours=1669.0
# Hourly wage => 8.867943274847377
# Bulgaria, 2000, empratio=41.851, gdpcap=12548.28509, laborshare=0.504459321498871, whours=1640.0
# Hourly wage => 9.222758587922833
# Bulgaria, 2001, empratio=41.22, gdpcap=13290.03434, laborshare=0.477585703134537, whours=1652.0
# Hourly wage => 9.320933082965677
# Bulgaria, 2002, empratio=41.731, gdpcap=14379.18142, laborshare=0.45359468460083, whours=1651.0
# Hourly wage => 9.466648562127789
# Bulgaria, 2003, empratio=43.272, gdpcap=15252.58177, laborshare=0.467773497104645, whours=1641.0
# Hourly wage => 10.047625155666053
# Bulgaria, 2004, empratio=44.781, gdpcap=16368.67485, laborshare=0.464562922716141, whours=1664.0
# Hourly wage => 10.204951798144922
# Bulgaria, 2005, empratio=45.075, gdpcap=17656.15328, laborshare=0.467453539371491, whours=1659.0
# Hourly wage => 11.037035043291063
# Bulgaria, 2006, empratio=47.358, gdpcap=19000.99586, laborshare=0.463686436414719, whours=1654.0
# Hourly wage => 11.247911670382772
# Bulgaria, 2007, empratio=49.864, gdpcap=20414.95281, laborshare=0.46705025434494, whours=1655.0
# Hourly wage => 11.553854159871282
# Bulgaria, 2008, empratio=51.785, gdpcap=21818.91502, laborshare=0.497731387615204, whours=1694.0
# Hourly wage => 12.379719172145682
# Bulgaria, 2009, empratio=50.412, gdpcap=21224.91368, laborshare=0.472637832164764, whours=1646.0
# Hourly wage => 12.089564479092575
# Bulgaria, 2010, empratio=48.003, gdpcap=21697.39698, laborshare=0.480661898851395, whours=1645.0
# Hourly wage => 13.207269824941063
# Bulgaria, 2011, empratio=46.633, gdpcap=22293.40502, laborshare=0.468075096607208, whours=1644.0
# Hourly wage => 13.611211211706948
# Bulgaria, 2012, empratio=46.65, gdpcap=22590.81378, laborshare=0.480667293071747, whours=1644.0
# Hourly wage => 14.15868715876176
# Bulgaria, 2013, empratio=46.957, gdpcap=22594.29695, laborshare=0.513021945953369, whours=1645.0
# Hourly wage => 15.006123999933548
# Bulgaria, 2014, empratio=47.801, gdpcap=22938.83029, laborshare=0.521066009998322, whours=1644.0
# Hourly wage => 15.209860024967346
# Bulgaria, 2015, empratio=49.252, gdpcap=23870.01164, laborshare=0.512713372707367, whours=1644.0
# Hourly wage => 15.114771698117845
# Bulgaria, 2016, empratio=49.272, gdpcap=24765.5618, laborshare=0.523164212703705, whours=1644.0
# Hourly wage => 15.994998666301482
# Bulgaria, 2017, empratio=51.99, gdpcap=25632.15208, laborshare=0.513985455036163, whours=1643.0
# Hourly wage => 15.423343093854173
# Bulgaria, 2018, empratio=52.434, gdpcap=26476.125, laborshare=0.527658760547638, whours=1645.0
# Hourly wage => 16.19678002104291
# ...
# Hourly wage => 1.448504162465212
# Uzbekistan, 2003, empratio=55.453, gdpcap=3711.778531, laborshare=0.470142990350723, whours=2124.0
# Hourly wage => 1.4816050922239348
# Uzbekistan, 2004, empratio=55.66, gdpcap=3939.530398, laborshare=0.470142990350723, whours=2122.0
# Hourly wage => 1.5681436352098814
# Uzbekistan, 2005, empratio=55.878, gdpcap=4160.95513, laborshare=0.470142990350723, whours=2120.0
# Hourly wage => 1.6513771980444774
# Uzbekistan, 2006, empratio=56.034, gdpcap=4413.722812, laborshare=0.470142990350723, whours=2118.0
# Hourly wage => 1.7484669966269317
# Uzbekistan, 2007, empratio=56.058, gdpcap=4764.563914, laborshare=0.470142990350723, whours=2116.0
# Hourly wage => 1.8884255159481267
# Uzbekistan, 2008, empratio=55.62, gdpcap=5115.643915, laborshare=0.470142990350723, whours=2114.0
# Hourly wage => 2.045475606849339
# Uzbekistan, 2009, empratio=55.178, gdpcap=5439.550681, laborshare=0.470142990350723, whours=2112.0
# Hourly wage => 2.194487564187627
# Uzbekistan, 2010, empratio=54.806, gdpcap=5760.80512, laborshare=0.470142990350723, whours=2110.0
# Hourly wage => 2.3420846490711447
# Uzbekistan, 2011, empratio=54.879, gdpcap=6100.25101, laborshare=0.470142990350723, whours=2108.0
# Hourly wage => 2.4791389873760035
# Uzbekistan, 2012, empratio=54.74, gdpcap=6435.564672, laborshare=0.470142990350723, whours=2106.0
# Hourly wage => 2.6245416209871597
# Uzbekistan, 2013, empratio=54.546, gdpcap=6797.774948, laborshare=0.470142990350723, whours=2104.0
# Hourly wage => 2.7847621285846285
# Uzbekistan, 2014, empratio=54.235, gdpcap=7145.109807, laborshare=0.470142990350723, whours=2102.0
# Hourly wage => 2.946636177468913
# Uzbekistan, 2015, empratio=53.997, gdpcap=7529.763643, laborshare=0.470142990350723, whours=2100.0
# Hourly wage => 3.1219244065183287
# Uzbekistan, 2016, empratio=53.876, gdpcap=7839.978201, laborshare=0.483196407556534, whours=2098.0
# Hourly wage => 3.3514884247886827
# Uzbekistan, 2017, empratio=53.464, gdpcap=8047.053755, laborshare=0.427631556987762, whours=2096.0
# Hourly wage => 3.070816902704726
# Uzbekistan, 2018, empratio=53.578, gdpcap=8348.960579, laborshare=0.427631556987762, whours=2094.0
# Hourly wage => 3.182284339741879
# Uzbekistan, 2019, empratio=53.669, gdpcap=8755.12594, laborshare=0.427631556987762, whours=2092.0
# Hourly wage => 3.3346246836810303
# Uzbekistan, 2020, empratio=52.579, gdpcap=8727.411049, laborshare=0.4550055339565411, whours=2090.0
# Hourly wage => 3.6136284915980714
# Uzbekistan, 2021, empratio=53.131, gdpcap=9247.643827, laborshare=0.4542595446403383, whours=2088.0
# Hourly wage => 3.7866631333709324
# Uzbekistan, 2022, empratio=53.597, gdpcap=9607.561673, laborshare=0.4535135553241356, whours=2086.0
# Hourly wage => 3.8971638721838295
# Uzbekistan, 2023, empratio=53.531, gdpcap=10007.6855, laborshare=0.4527675660079329, whours=2084.0
# Hourly wage => 4.061681701581604
# South Africa, 1991, empratio=48.118, gdpcap=10472.1586, laborshare=0.602886855602264, whours=2180.0
# Hourly wage => 6.018773010350136
# South Africa, 1992, empratio=47.968, gdpcap=10065.91609, laborshare=0.599729776382446, whours=2160.0
# Hourly wage => 5.826443714926622
# South Africa, 1993, empratio=47.932, gdpcap=9989.177217, laborshare=0.593380570411682, whours=2140.0
# Hourly wage => 5.778614402887384
# South Africa, 1994, empratio=48.062, gdpcap=10143.20628, laborshare=0.589723587036133, whours=2120.0
# Hourly wage => 5.870648203116014
# South Africa, 1995, empratio=48.331, gdpcap=10331.46922, laborshare=0.582183599472046, whours=2100.0
# Hourly wage => 5.926209184812126
# South Africa, 1996, empratio=48.448, gdpcap=10636.86433, laborshare=0.581943809986115, whours=2080.0
# Hourly wage => 6.142645955959129
# South Africa, 1997, empratio=48.343, gdpcap=10783.46116, laborshare=0.580091595649719, whours=2060.0
# Hourly wage => 6.281363604344249
# South Africa, 1998, empratio=48.044, gdpcap=10706.77768, laborshare=0.588794410228729, whours=2040.0
# Hourly wage => 6.432105179673656
# South Africa, 1999, empratio=47.746, gdpcap=10844.91729, laborshare=0.583491563796997, whours=2020.0
# Hourly wage => 6.561036629050664
# South Africa, 2000, empratio=47.557, gdpcap=11197.5149, laborshare=0.561061501502991, whours=2000.0
# Hourly wage => 6.605225858334328
# South Africa, 2001, empratio=47.377, gdpcap=11401.43105, laborshare=0.545413494110107, whours=2376.0
# Hourly wage => 5.524223622086692
# South Africa, 2002, empratio=47.163, gdpcap=11711.88395, laborshare=0.529168426990509, whours=2383.0
# Hourly wage => 5.514361325669596
# South Africa, 2003, empratio=46.877, gdpcap=11937.71542, laborshare=0.527124285697937, whours=2319.0
# Hourly wage => 5.788601972825757
# South Africa, 2004, empratio=46.729, gdpcap=12356.31634, laborshare=0.524096190929413, whours=2342.0
# Hourly wage => 5.91734163375622
# South Africa, 2005, empratio=46.615, gdpcap=12877.30631, laborshare=0.518273770809174, whours=2399.0
# Hourly wage => 5.967993206032985
# South Africa, 2006, empratio=46.565, gdpcap=13460.68942, laborshare=0.513675093650818, whours=2316.0
# Hourly wage => 6.4114705282465625
# South Africa, 2007, empratio=46.474, gdpcap=14033.40084, laborshare=0.51281875371933, whours=2322.0
# Hourly wage => 6.668905449334992
# South Africa, 2008, empratio=46.314, gdpcap=14315.18965, laborshare=0.515515029430389, whours=2284.0
# Hourly wage => 6.976378683596171
# South Africa, 2009, empratio=44.402, gdpcap=13927.72889, laborshare=0.522477626800537, whours=2249.0
# Hourly wage => 7.2871215659817175
# South Africa, 2010, empratio=40.8, gdpcap=14182.33428, laborshare=0.528297245502472, whours=2236.0
# Hourly wage => 8.212853983521963
# South Africa, 2011, empratio=42.33, gdpcap=14451.92918, laborshare=0.532650709152222, whours=2255.0
# Hourly wage => 8.064427084987598
# South Africa, 2012, empratio=42.122, gdpcap=14581.58896, laborshare=0.537096083164215, whours=2224.0
# Hourly wage => 8.360130760893759
# South Africa, 2013, empratio=42.411, gdpcap=14699.06681, laborshare=0.54379814863205, whours=2212.0
# Hourly wage => 8.520475915777777
# South Africa, 2014, empratio=42.131, gdpcap=14661.26243, laborshare=0.552340626716614, whours=2209.0
# Hourly wage => 8.70123448844836
# South Africa, 2015, empratio=43.184, gdpcap=14559.47438, laborshare=0.561690330505371, whours=1700.0
# Hourly wage => 11.139632293669063
# South Africa, 2016, empratio=42.583, gdpcap=14519.03086, laborshare=0.568343043327332, whours=2218.0
# Hourly wage => 8.736759491981841
# South Africa, 2017, empratio=42.885, gdpcap=14591.43668, laborshare=0.570414483547211, whours=2197.0
# Hourly wage => 8.833913202396023
# South Africa, 2018, empratio=42.49, gdpcap=14571.37563, laborshare=0.57088828086853, whours=2191.0
# Hourly wage => 8.935576414844457
# South Africa, 2019, empratio=41.722, gdpcap=14370.23804, laborshare=0.57088828086853, whours=2191.0
# Hourly wage => 8.974444865919644
# South Africa, 2020, empratio=38.719, gdpcap=13266.78581, laborshare=0.5325662724196603, whours=2216.0
# Hourly wage => 8.234656510373947
# South Africa, 2021, empratio=36.798, gdpcap=13711.29357, laborshare=0.531040214317771, whours=2217.0
# Hourly wage => 8.925158382740785
# South Africa, 2022, empratio=37.999, gdpcap=13777.19275, laborshare=0.5295141562158823, whours=2219.0
# Hourly wage => 8.651847179299267
# South Africa, 2023, empratio=39.742, gdpcap=13690.38946, laborshare=0.5279880981139935, whours=2220.0
# Hourly wage => 8.192892233085
# Zambia, 1991, empratio=48.612, gdpcap=2364.86234, laborshare=0.445720881223679, whours=1980.0
# Hourly wage => 1.0951161060924928
# Zambia, 1992, empratio=48.208, gdpcap=2268.498122, laborshare=0.445720881223679, whours=1960.0
# Hourly wage => 1.0701045702382583
# Zambia, 1993, empratio=48.102, gdpcap=2365.629536, laborshare=0.445720881223679, whours=1940.0
# Hourly wage => 1.1299125970657318
# Zambia, 1994, empratio=48.73, gdpcap=2110.583256, laborshare=0.445720881223679, whours=1920.0
# Hourly wage => 1.0054670171953684
# Zambia, 1995, empratio=49.827, gdpcap=2119.956429, laborshare=0.445720881223679, whours=1900.0
# Hourly wage => 0.9980942985780099
# Zambia, 1996, empratio=50.75, gdpcap=2197.195649, laborshare=0.445720881223679, whours=1880.0
# Hourly wage => 1.026450037619865
# Zambia, 1997, empratio=51.941, gdpcap=2223.457454, laborshare=0.445720881223679, whours=1860.0
# Hourly wage => 1.0258138377437733
# Zambia, 1998, empratio=52.711, gdpcap=2157.573393, laborshare=0.445720881223679, whours=1840.0
# Hourly wage => 0.9915382669411499
# Zambia, 1999, empratio=52.397, gdpcap=2198.18913, laborshare=0.445720881223679, whours=1820.0
# Hourly wage => 1.0274252302003621
# Zambia, 2000, empratio=52.104, gdpcap=2220.565371, laborshare=0.445720881223679, whours=1800.0
# Hourly wage => 1.0553170944189676
# Zambia, 2001, empratio=51.754, gdpcap=2268.969656, laborshare=0.445720881223679, whours=1780.0
# Hourly wage => 1.0978114209074952
# Zambia, 2002, empratio=51.265, gdpcap=2299.332892, laborshare=0.445720881223679, whours=1760.0
# Hourly wage => 1.1358767310330793
# Zambia, 2003, empratio=50.868, gdpcap=2383.876117, laborshare=0.445720881223679, whours=1740.0
# Hourly wage => 1.2004739826918736
# Zambia, 2004, empratio=50.446, gdpcap=2471.720733, laborshare=0.445720881223679, whours=1720.0
# Hourly wage => 1.2697177724137874
# Zambia, 2005, empratio=50.06, gdpcap=2564.47561, laborshare=0.445720881223679, whours=1700.0
# Hourly wage => 1.3431415580900936
# Zambia, 2006, empratio=51.6, gdpcap=2673.461519, laborshare=0.445720881223679, whours=1680.0
# Hourly wage => 1.3746050481799965
# Zambia, 2007, empratio=53.135, gdpcap=2796.352933, laborshare=0.445720881223679, whours=1660.0
# Hourly wage => 1.4130781828839925
# Zambia, 2008, empratio=54.642, gdpcap=2908.143625, laborshare=0.445720881223679, whours=1640.0
# Hourly wage => 1.4464665562138213
# Zambia, 2009, empratio=53.011, gdpcap=3065.844201, laborshare=0.445720881223679, whours=1620.0
# Hourly wage => 1.591226674086773
# Zambia, 2010, empratio=51.411, gdpcap=3266.507493, laborshare=0.445720881223679, whours=1600.0
# Hourly wage => 1.769989153955027
# Zambia, 2011, empratio=52.928, gdpcap=3335.643395, laborshare=0.400977462530136, whours=1580.0
# Hourly wage => 1.599399691331941
# Zambia, 2012, empratio=54.468, gdpcap=3474.552528, laborshare=0.442422121763229, whours=1560.0
# Hourly wage => 1.8091296390630103
# Zambia, 2013, empratio=54.748, gdpcap=3535.22449, laborshare=0.392384111881256, whours=1540.0
# Hourly wage => 1.6452785345293006
# Zambia, 2014, empratio=55.073, gdpcap=3585.577485, laborshare=0.398576259613037, whours=1520.0
# Hourly wage => 1.707214996129563
# Zambia, 2015, empratio=55.349, gdpcap=3576.925448, laborshare=0.352824509143829, whours=1500.0
# Hourly wage => 1.5200840309486723
# Zambia, 2016, empratio=55.655, gdpcap=3598.17166, laborshare=0.340859472751617, whours=1480.0
# Hourly wage => 1.4889885016734496
# Zambia, 2017, empratio=55.955, gdpcap=3612.505977, laborshare=0.283626139163971, whours=1460.0
# Hourly wage => 1.2541892432682318
# Zambia, 2018, empratio=55.538, gdpcap=3646.959665, laborshare=0.390300542116165, whours=1440.0
# Hourly wage => 1.7798253427149073
# Zambia, 2019, empratio=56.239, gdpcap=3591.564189, laborshare=0.390300542116165, whours=1420.0
# Hourly wage => 1.7553222301647027
# Zambia, 2020, empratio=57.2, gdpcap=3391.595412, laborshare=0.3751089271947077, whours=1400.0
# Hourly wage => 1.5886834621301353
# Zambia, 2021, empratio=56.993, gdpcap=3503.034914, laborshare=0.3718249504202102, whours=1420.0
# Hourly wage => 1.6094338534017087
# Zambia, 2022, empratio=55.963, gdpcap=3585.123791, laborshare=0.3685409736457119, whours=1440.0
# Hourly wage => 1.6395567564674998
# Zambia, 2023, empratio=55.91, gdpcap=3673.484197, laborshare=0.3652569968712145, whours=1460.0
# Hourly wage => 1.6437447240919052
# Zimbabwe, 1991, empratio=63.895, gdpcap=4126.405247, laborshare=0.533381104469299, whours=2297.0
# Hourly wage => 1.4996214151903275
# Zimbabwe, 1992, empratio=63.868, gdpcap=3649.891947, laborshare=0.533381104469299, whours=2294.0
# Hourly wage => 1.3287427372986729
# Zimbabwe, 1993, empratio=63.919, gdpcap=3634.750494, laborshare=0.533381104469299, whours=2291.0
# Hourly wage => 1.3239060581290791
# Zimbabwe, 1994, empratio=63.802, gdpcap=3965.730986, laborshare=0.533381104469299, whours=2288.0
# Hourly wage => 1.4490072689239868
# Zimbabwe, 1995, empratio=63.179, gdpcap=3935.280057, laborshare=0.533381104469299, whours=2285.0
# Hourly wage => 1.4539662278017589
# Zimbabwe, 1996, empratio=62.494, gdpcap=4271.47993, laborshare=0.533381104469299, whours=2282.0
# Hourly wage => 1.5975778602225876
# Zimbabwe, 1997, empratio=61.683, gdpcap=4304.406272, laborshare=0.533381104469299, whours=2279.0
# Hourly wage => 1.6332063841254691
# Zimbabwe, 1998, empratio=61.762, gdpcap=4342.858177, laborshare=0.533381104469299, whours=2276.0
# Hourly wage => 1.6478575440607872
# Zimbabwe, 1999, empratio=61.789, gdpcap=4238.195198, laborshare=0.533381104469299, whours=2273.0
# Hourly wage => 1.6095629962409925
# Zimbabwe, 2000, empratio=61.839, gdpcap=4071.022001, laborshare=0.533381104469299, whours=2270.0
# Hourly wage => 1.5468662379223608
# Zimbabwe, 2001, empratio=61.972, gdpcap=4102.086705, laborshare=0.533381104469299, whours=2267.0
# Hourly wage => 1.5573829999678321
# Zimbabwe, 2002, empratio=62.137, gdpcap=3701.458078, laborshare=0.533381104469299, whours=2264.0
# Hourly wage => 1.4034073842861308
# Zimbabwe, 2003, empratio=62.348, gdpcap=3036.055749, laborshare=0.533381104469299, whours=2261.0
# Hourly wage => 1.1487467063512686
# Zimbabwe, 2004, empratio=62.633, gdpcap=2828.845581, laborshare=0.533381104469299, whours=2258.0
# Hourly wage => 1.0668901752389786
# Zimbabwe, 2005, empratio=62.549, gdpcap=2642.174368, laborshare=0.533381104469299, whours=2255.0
# Hourly wage => 0.9991534318543926
# Zimbabwe, 2006, empratio=62.499, gdpcap=2519.829359, laborshare=0.533381104469299, whours=2252.0
# Hourly wage => 0.9549206901538384
# Zimbabwe, 2007, empratio=62.382, gdpcap=2395.99073, laborshare=0.533381104469299, whours=2249.0
# Hourly wage => 0.9109069381351099
# Zimbabwe, 2008, empratio=62.213, gdpcap=1949.036429, laborshare=0.533381104469299, whours=2246.0
# Hourly wage => 0.7439892951216802
# Zimbabwe, 2009, empratio=62.249, gdpcap=2152.795285, laborshare=0.533381104469299, whours=2243.0
# Hourly wage => 0.8223916785680033
# Zimbabwe, 2010, empratio=62.367, gdpcap=2572.769992, laborshare=0.533381104469299, whours=2240.0
# Hourly wage => 0.982280936603399
# Zimbabwe, 2011, empratio=62.524, gdpcap=2897.100919, laborshare=0.533381104469299, whours=2237.0
# Hourly wage => 1.1048123281484163
# Zimbabwe, 2012, empratio=62.822, gdpcap=3299.259847, laborshare=0.533381104469299, whours=2234.0
# Hourly wage => 1.2538893701113423
# Zimbabwe, 2013, empratio=62.967, gdpcap=3357.128269, laborshare=0.533381104469299, whours=2231.0
# Hourly wage => 1.2746559831086992
# Zimbabwe, 2014, empratio=63.091, gdpcap=3360.552173, laborshare=0.533381104469299, whours=2228.0
# Hourly wage => 1.2751629067078103
# Zimbabwe, 2015, empratio=62.658, gdpcap=3382.923133, laborshare=0.533381104469299, whours=2225.0
# Hourly wage => 1.294265016341094
# Zimbabwe, 2016, empratio=62.251, gdpcap=3366.34429, laborshare=0.533381104469299, whours=2222.0
# Hourly wage => 1.2980928876985194
# Zimbabwe, 2017, empratio=61.851, gdpcap=3453.509708, laborshare=0.533381104469299, whours=2219.0
# Hourly wage => 1.342129059208768
# Zimbabwe, 2018, empratio=61.442, gdpcap=3572.983589, laborshare=0.533381104469299, whours=2216.0
# Hourly wage => 1.399695440041881
# Zimbabwe, 2019, empratio=60.944, gdpcap=3294.806084, laborshare=0.533381104469299, whours=2213.0
# Hourly wage => 1.3030321051635068
# Zimbabwe, 2020, empratio=59.18, gdpcap=2987.269823, laborshare=0.533381104469299, whours=2210.0
# Hourly wage => 1.2182736291454919
# Zimbabwe, 2021, empratio=59.159, gdpcap=3184.785451, laborshare=0.533381104469299, whours=2207.0
# Hourly wage => 1.3010519846721618
# Zimbabwe, 2022, empratio=58.636, gdpcap=3323.121932, laborshare=0.533381104469299, whours=2204.0
# Hourly wage => 1.3715384167592566
# Zimbabwe, 2023, empratio=59.308, gdpcap=3442.251327, laborshare=0.533381104469299, whours=2201.0
# Hourly wage => 1.4065231380049004
# Done! '~/Downloads/Countries_Wages_Estimates_GOOD.csv' created with 'estimated_hourly_wage' and its log-transformation.
# df_compare created with 1041 rows

# %%
# 1. Extract the list of unique countries
countries_list = df_final["country"].dropna().unique().tolist()

# 2. Get the count
num_countries = len(countries_list)

print(f"Number of countries with estimated wages: {num_countries}")
print("List of countries:", countries_list)
# Out:
# Number of countries with estimated wages: 124
# List of countries: ['Angola', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina', 'Belarus', 'Bolivia', 'Brazil', 'Barbados', 'Botswana', 'Central African Republic', 'Canada', 'Switzerland', 'Chile', 'China', 'Cameroon', 'Colombia', 'Cabo Verde', 'Costa Rica', 'Cyprus', 'Czechia', 'Germany', 'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'Spain', 'Estonia', 'Finland', 'Fiji', 'France', 'Gabon', 'United Kingdom', 'Georgia', 'Guinea', 'Greece', 'Guatemala', 'Hong Kong SAR, China', 'Honduras', 'Croatia', 'Hungary', 'Indonesia', 'India', 'Ireland', 'Iran, Islamic Rep.', 'Iraq', 'Iceland', 'Italy', 'Jamaica', 'Jordan', 'Japan', 'Kazakhstan', 'Kenya', 'Kyrgyz Republic', 'Korea, Rep.', 'Kuwait', 'Lao PDR', 'Lebanon', 'Sri Lanka', 'Lesotho', 'Luxembourg', 'Latvia', 'Macao SAR, China', 'Morocco', 'Moldova', 'Mexico', 'North Macedonia', 'Malta', 'Mongolia', 'Mozambique', 'Mauritania', 'Mauritius', 'Malaysia', 'Namibia', 'Niger', 'Nigeria', 'Nicaragua', 'Netherlands', 'Norway', 'New Zealand', 'Oman', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Paraguay', 'Qatar', 'Romania', 'Russian Federation', 'Rwanda', 'Saudi Arabia', 'Sudan', 'Senegal', 'Singapore', 'Sierra Leone', 'Serbia', 'Suriname', 'Slovak Republic', 'Slovenia', 'Sweden', 'Eswatini', 'Chad', 'Togo', 'Thailand', 'Tajikistan', 'Trinidad and Tobago', 'Tunisia', 'Tanzania', 'Ukraine', 'Uruguay', 'United States', 'Uzbekistan', 'South Africa', 'Zambia', 'Zimbabwe']

# %%
# Initial slope and intercept for Norway

import pandas as pd
from sklearn.linear_model import LinearRegression

# Filter the merged dataframe for Norway and drop any missing values
df_norway = df_compare[df_compare["country"] == "Norway"].dropna(subset=["estimated_hourly_wage", "oecd_hourly_wage"]).sort_values("year")

if len(df_norway) < 2:
    print("Not enough data for Norway to run a regression.")
else:
    # Prepare the predictor and response variables
    X = df_norway[["estimated_hourly_wage"]].values  # Estimated wage as predictor
    y = df_norway["oecd_hourly_wage"].values           # True OECD hourly wage as response

    # Fit the linear regression model: true wage = intercept + slope * estimated wage
    model = LinearRegression().fit(X, y)
    intercept = round(model.intercept_, 3)
    slope = round(model.coef_[0], 3)

    print("Regression results for Norway:")
    print("Intercept:", intercept)
    print("Slope:", slope)
# Out:
# Regression results for Norway:
# Intercept: -27.176
# Slope: 1.494

# %%
# Fixing Norway code blocks below:

# %%
# Can be ingored # First code to try to see Norway estimate with non linear regressions, doesn't improve, so need to check with adding a variable

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# ---- Configuration ----
# Set a manual adjustment factor (e.g., to adjust for oil revenue anomaly)
adjustment_factor = 0.0  # change this value as needed; set to 0 for no adjustment

# Select the degrees of polynomial to test: 1 = linear, 2 = quadratic, 3 = cubic
degrees = [1, 2, 3]

# ---- Data Preparation ----
# Filter the merged dataframe for Norway, drop missing values, and sort by year
df_norway = df_compare[df_compare["country"] == "Norway"].dropna(subset=["estimated_hourly_wage", "oecd_hourly_wage"]).sort_values("year")

if len(df_norway) < 2:
    print("Not enough data for Norway to run a regression.")
else:
    # Prepare predictor and response variables.
    # Apply a manual adjustment (if any) to estimated wage:
    X = (df_norway[["estimated_hourly_wage"]].values - adjustment_factor)
    y = df_norway["oecd_hourly_wage"].values

    # Create a range for plotting predictions. We'll use a fine grid between min and max estimated wage.
    X_plot = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)

    # We'll store results for printing later.
    results = {}

    plt.figure(figsize=(10, 6))
    plt.scatter(X, y, color="black", label="Data Points")

    # We'll compute the mean estimated wage (after adjustment) to use for derivative calculation.
    X_mean = np.mean(X)

    for deg in degrees:
        # Create a pipeline with PolynomialFeatures and LinearRegression
        model = Pipeline([
            ('poly', PolynomialFeatures(degree=deg, include_bias=False)),
            ('lin_reg', LinearRegression())
        ])
        model.fit(X, y)
        y_pred = model.predict(X_plot)

        # For degree=1, we can easily get intercept and slope.
        if deg == 1:
            intercept = model.named_steps["lin_reg"].intercept_
            slope = model.named_steps["lin_reg"].coef_[0]
        else:
            # For non-linear models, we compute the derivative at the mean of X.
            # The polynomial model is: f(x) = c0*x + c1*x^2 + ... + c_{deg-1} * x^deg + intercept.
            # Its derivative is: f'(x) = c0 + 2*c1*x + ... + deg*c_{deg-1} * x^(deg-1)
            lin_coefs = model.named_steps["lin_reg"].coef_
            intercept = model.named_steps["lin_reg"].intercept_
            derivative = lin_coefs[0]
            for d in range(2, deg+1):
                derivative += d * lin_coefs[d-1] * (X_mean ** (d-1))
            slope = derivative

        # Store rounded results (3 decimals)
        results[f"degree_{deg}"] = {"intercept": round(intercept, 3),
                                    "slope (deriv at mean)": round(slope, 3)}

        # Plot the fitted curve
        plt.plot(X_plot + adjustment_factor, y_pred, label=f"Degree {deg} Fit")

    plt.xlabel("Estimated Hourly Wage" + (" (adjusted)" if adjustment_factor else ""))
    plt.ylabel("True OECD Hourly Wage")
    plt.title("Non-linear Regression Fits for Norway")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print the regression parameters for each model
    print("Regression parameters for Norway (rounded to 3 decimals):")
    for key, params in results.items():
        print(f"{key}: Intercept = {params['intercept']}, Slope (local derivative at mean) = {params['slope (deriv at mean)']}")
# Out:
# Regression parameters for Norway (rounded to 3 decimals):
# degree_1: Intercept = -23.53, Slope (local derivative at mean) = 1.408
# degree_2: Intercept = -59.618, Slope (local derivative at mean) = 1.465
# degree_3: Intercept = -182.063, Slope (local derivative at mean) = 1.356

# %%
# IGNORE AS WELL # Second code with the plots

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# Filter the merged dataframe for Norway, drop missing values, and sort by year
df_norway = df_compare[df_compare["country"] == "Norway"].dropna(
    subset=["estimated_hourly_wage", "oecd_hourly_wage"]
).sort_values("year")

if len(df_norway) < 2:
    print("Not enough data for Norway to run a regression.")
else:
    # Use "year" as the predictor
    X_year = df_norway[["year"]].values
    # True OECD hourly wage (as reported) and our estimated wage
    y_true = df_norway["oecd_hourly_wage"].values
    y_est = df_norway["estimated_hourly_wage"].values

    # Create a grid for plotting regression predictions
    X_plot = np.linspace(df_norway["year"].min(), df_norway["year"].max(), 100).reshape(-1,1)

    # Start plotting: plot both the true OECD wage and the estimated wage over time
    plt.figure(figsize=(10,6))
    plt.plot(df_norway["year"], y_true, color="blue", marker="o", linestyle="-", label="True OECD Wage")
    plt.plot(df_norway["year"], y_est, color="green", marker="x", linestyle="--", label="Estimated Wage")

    # Dictionary to store regression parameters for each model
    results = {}
    degrees = [1, 2, 3]
    colors = ["red", "orange", "purple"]

    for i, deg in enumerate(degrees):
        # Create a pipeline to fit a polynomial regression model of specified degree
        model = Pipeline([
            ("poly", PolynomialFeatures(degree=deg, include_bias=False)),
            ("lin_reg", LinearRegression())
        ])
        model.fit(X_year, y_true)
        y_pred = model.predict(X_plot)

        # For linear (degree 1), we can directly obtain slope and intercept
        if deg == 1:
            intercept = model.named_steps["lin_reg"].intercept_
            slope = model.named_steps["lin_reg"].coef_[0]
        else:
            # For polynomial regression, approximate the local slope by computing the derivative at the mean year.
            coefs = model.named_steps["lin_reg"].coef_
            intercept = model.named_steps["lin_reg"].intercept_
            X_mean = np.mean(X_year)
            # The polynomial model: y = c0*x + c1*x^2 + ... + c_{deg-1}*x^deg + intercept
            # Its derivative is: f'(x) = c0 + 2*c1*x + ... + deg*c_{deg-1}*x^(deg-1)
            slope = sum((d+1) * coefs[d] * (X_mean ** d) for d in range(len(coefs)))

        # Round the regression parameters to 3 decimals
        intercept = round(intercept, 3)
        slope = round(slope, 3)
        results[f"degree_{deg}"] = {"intercept": intercept, "slope (local derivative at mean)": slope}

        # Plot the fitted regression curve
        plt.plot(X_plot, y_pred, color=colors[i], linestyle="-", label=f"Degree {deg} Fit (slope={slope})")

    plt.xlabel("Year")
    plt.ylabel("Hourly Wage")
    plt.title("True OECD Wage and Estimated Wage with Regression Fits (Norway)")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print the regression parameters for each model
    print("Regression parameters for Norway (using year as predictor):")
    for key, params in results.items():
        print(f"{key}: Intercept = {params['intercept']}, Slope (local derivative at mean) = {params['slope (local derivative at mean)']}")
# Out:
# Regression parameters for Norway (using year as predictor):
# degree_1: Intercept = -1840.908, Slope (local derivative at mean) = 0.938
# degree_2: Intercept = -52972.565, Slope (local derivative at mean) = 0.938
# degree_3: Intercept = 10570007.525, Slope (local derivative at mean) = 1.152

# %%
# Comparing norwegian oil, estimate wages and true wages

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. Load your existing wage data
df_est = pd.read_csv(os.path.expanduser('~/Downloads/Countries_Wages_Estimates_GOOD.csv'))
df_oecd = pd.read_csv(os.path.expanduser('~/Documents/Project_Wage_Convergence/OECD_wages_merged.csv'))
df_oecd.rename(columns={"Country": "country", "Wages": "oecd_annual_wage", "Year": "year"}, inplace=True)
df_oecd["year"] = pd.to_numeric(df_oecd["year"], errors="coerce")

df_compare = pd.merge(
    df_est,
    df_oecd[["country", "year", "oecd_annual_wage"]],
    on=["country", "year"],
    how="inner"
)

df_compare["oecd_hourly_wage"] = df_compare["oecd_annual_wage"] / df_compare["whours"]
df_compare["diff"] = df_compare["estimated_hourly_wage"] - df_compare["oecd_hourly_wage"]
df_compare["ratio"] = df_compare["estimated_hourly_wage"] / df_compare["oecd_hourly_wage"]

df_compare["log_estimated_hourly_wage"] = np.log(df_compare["estimated_hourly_wage"])
df_compare["log_oecd_hourly_wage"] = np.log(df_compare["oecd_hourly_wage"])

# 2. Load Norwegian oil revenue from Excel
df_oil = pd.read_excel(
    os.path.expanduser('~/Documents/Project_Wage_Convergence/Norwegian_Oil_revenue.xlsx'),
    sheet_name='Noe'
)
df_oil.rename(
    columns={
        "Year": "year",
        "NCF converted in PPP": "oil_revenue_billion_usd"
    },
    inplace=True
)

# 3. Merge with df_compare but only for Norway
df_norway = df_compare[df_compare["country"] == "Norway"].copy()
df_norway_merged = pd.merge(df_norway, df_oil[["year", "oil_revenue_billion_usd"]], on="year", how="inner")

# ---------------------------------------------------
# 4. Save the required data as a CSV file for LaTeX
# ---------------------------------------------------
# Select only the columns needed for your LaTeX plot
df_norway_export = df_norway_merged[["year", "log_estimated_hourly_wage", "log_oecd_hourly_wage", "oil_revenue_billion_usd"]]
output_csv = os.path.expanduser('~/Documents/Project_Wage_Convergence/norway_data.csv')
df_norway_export.to_csv(output_csv, index=False)
print(f"CSV data saved to {output_csv}")

# ---------------------------------------------------
# 5. Plot a Dual-Axis Chart for Norway: Log Wages vs. Oil Revenue
# ---------------------------------------------------
fig, ax1 = plt.subplots(figsize=(8, 5))

# Primary y-axis: Log wages
ax1.plot(
    df_norway_merged["year"],
    df_norway_merged["log_estimated_hourly_wage"],
    marker='o', color='blue', label='Log Estimated Wage'
)
ax1.plot(
    df_norway_merged["year"],
    df_norway_merged["log_oecd_hourly_wage"],
    marker='x', color='red', label='Log OECD Wage'
)
ax1.set_xlabel("Year")
ax1.set_ylabel("Log Hourly Wage (PPP)")
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_title("Norway: Log Wages vs. Oil Revenue")

# Secondary y-axis: Oil revenue
ax2 = ax1.twinx()
ax2.plot(
    df_norway_merged["year"],
    df_norway_merged["oil_revenue_billion_usd"],
    marker='s', color='green', linestyle='--', label='Oil Revenue (Billion USD PPP)'
)
ax2.set_ylabel("Oil Revenue (Billion USD PPP)")
ax2.tick_params(axis='y', labelcolor='black')

# Combine legends from both axes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='best')

plt.tight_layout()

# 6. Save the plot to a PDF file (for reference) and display it
output_dir = os.path.expanduser('~/Documents/Project_Wage_Convergence/')
output_file = os.path.join(output_dir, 'Norway_Wage_Oil_comparison.pdf')
os.makedirs(output_dir, exist_ok=True)
plt.savefig(output_file)
print(f"Plot saved to {output_file}")

plt.show()
# Out:
# CSV data saved to /Users/noenotter/Documents/Project_Wage_Convergence/norway_data.csv
# Plot saved to /Users/noenotter/Documents/Project_Wage_Convergence/Norway_Wage_Oil_comparison.pdf

# %%
# Adjusting Norwegian wages estimate

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 1. We assume df_norway_merged is already defined and contains:
#    [year, estimated_hourly_wage, oecd_hourly_wage, log_estimated_hourly_wage, log_oecd_hourly_wage, oil_revenue_billion_usd]

# Drop any rows that lack data for these key variables
df_norway_model = df_norway_merged.dropna(subset=[
    "year", "log_estimated_hourly_wage", "oil_revenue_billion_usd", "log_oecd_hourly_wage"
]).copy()

if len(df_norway_model) < 5:
    print("Not enough data points for regression.")
else:
    # 2. Prepare the regression inputs: predict log_oecd_hourly_wage using year, log_estimated_hourly_wage, and oil_revenue_billion_usd.
    X = df_norway_model[["year", "log_estimated_hourly_wage", "oil_revenue_billion_usd"]]
    y = df_norway_model["log_oecd_hourly_wage"]

    # Fit the linear regression
    model = LinearRegression().fit(X, y)

    # Extract coefficients and print them
    intercept = model.intercept_
    coefs = model.coef_
    print("Regression Model: log_oecd_hourly_wage = intercept + a*year + b*log_est + c*oil_revenue")
    print(f"Intercept: {intercept:.3f}")
    print(f"year coefficient: {coefs[0]:.3f}")
    print(f"log_estimated_hourly_wage coefficient: {coefs[1]:.3f}")
    print(f"oil_revenue_billion_usd coefficient: {coefs[2]:.3f}")

    # 3. Generate new predictions (on the log scale) and exponentiate to get wage in levels.
    df_norway_model["log_estimated_wage_with_oil"] = model.predict(X)
    df_norway_model["estimated_wage_with_oil"] = np.exp(df_norway_model["log_estimated_wage_with_oil"])

    # 4. Plot the comparison:
    plt.figure(figsize=(9,6))

    # Plot the true OECD wage (red)
    plt.plot(
        df_norway_model["year"],
        df_norway_model["oecd_hourly_wage"],
        marker='o', color='red', label='True OECD Wage'
    )

    # Plot the old estimated wage (blue)
    plt.plot(
        df_norway_model["year"],
        df_norway_model["estimated_hourly_wage"],
        marker='x', color='blue', label='Old Estimated Wage'
    )

    # Plot the new oil-adjusted wage (green)
    plt.plot(
        df_norway_model["year"],
        df_norway_model["estimated_wage_with_oil"],
        marker='s', color='green', label='New Estimated Wage (Oil-Adjusted)'
    )

    plt.title("Norway: Comparing Old vs. New Wage Estimates to True Wage")
    plt.xlabel("Year")
    plt.ylabel("Hourly Wage (PPP)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    # 5. Save the plot to a PDF file for LaTeX inclusion
    output_dir = os.path.expanduser('~/Documents/Project_Wage_Convergence/')
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, 'Norway_Wage_oil_adjusted_comparison.pdf')
    plt.savefig(output_file)
    print(f"Plot saved to {output_file}")

    # 6. Show the plot
    plt.show()

    # 7. (Optional) Evaluate the fit via MSE
    mse_old = np.mean((df_norway_model["estimated_hourly_wage"] - df_norway_model["oecd_hourly_wage"])**2)
    mse_new = np.mean((df_norway_model["estimated_wage_with_oil"] - df_norway_model["oecd_hourly_wage"])**2)
    print(f"Old Estimate MSE: {mse_old:.3f}")
    print(f"New Oil-Adjusted Estimate MSE: {mse_new:.3f}")

    if mse_new < mse_old:
        print("The new oil-adjusted estimate has a lower MSE, indicating a better fit.")
    else:
        print("The new oil-adjusted estimate does not improve MSE compared to the old estimate.")



import numpy as np
import statsmodels.api as sm

# make sure df_norway exists and has oecd_hourly_wage & estimated_hourly_wage
log_oecd = np.log(df_norway["oecd_hourly_wage"])
log_est = np.log(df_norway["estimated_hourly_wage"])

# add_constant will now work
X = sm.add_constant(log_est)
model = sm.OLS(log_oecd, X).fit()

print(model.summary())
print("MSE on log-scale:", model.mse_resid)
# Out:
# Regression Model: log_oecd_hourly_wage = intercept + a*year + b*log_est + c*oil_revenue
# Intercept: -45.505
# year coefficient: 0.025
# log_estimated_hourly_wage coefficient: -0.133
# oil_revenue_billion_usd coefficient: 0.000
# Plot saved to /Users/noenotter/Documents/Project_Wage_Convergence/Norway_Wage_oil_adjusted_comparison.pdf
# Old Estimate MSE: 41.705
# New Oil-Adjusted Estimate MSE: 5.482
# The new oil-adjusted estimate has a lower MSE, indicating a better fit.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       oecd_hourly_wage   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     130.0
# Date:                Sat, 26 Apr 2025   Prob (F-statistic):           1.28e-12
# Time:                        10:00:52   Log-Likelihood:                 29.042
# No. Observations:                  33   AIC:                            -54.08
# Df Residuals:                      31   BIC:                            -51.09
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -2.9025      0.580     -5.001      0.000      -4.086      -1.719
# estimated_hourly_wage     1.7281      0.152     11.403      0.000       1.419       2.037
# ==============================================================================
# Omnibus:                        0.132   Durbin-Watson:                   0.486
# Prob(Omnibus):                  0.936   Jarque-Bera (JB):                0.349
# Skew:                          -0.025   Prob(JB):                        0.840
# Kurtosis:                       2.499   Cond. No.                         132.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MSE on log-scale: 0.010721852590969829

# %%
# Update our wages list with the new value for Norway

import pandas as pd

# 1. Load the existing final wages file (wages_final)
df_final = pd.read_csv('~/Downloads/Countries_Wages_Estimates_GOOD.csv')

# 2. Assume df_norway_model is already defined from previous analysis,
#    and it contains the new oil-adjusted wage estimates for Norway.
#    We extract just the "year" and "estimated_wage_with_oil" columns.
df_norway_new = df_norway_model[['year', 'estimated_wage_with_oil']]

# 3. Update df_final for rows where country == "Norway"
#    We perform a merge on "year" for the Norway rows.
df_norway_final = df_final[df_final["country"] == "Norway"].merge(
    df_norway_new, on="year", how="left"
)

# 4. Replace the old estimated_hourly_wage with the new oil-adjusted wage for Norway
df_final.loc[df_final["country"] == "Norway", "estimated_hourly_wage"] = df_norway_final["estimated_wage_with_oil"].values

# 5. Save the updated file
output_path = '~/Documents/Project_Wage_Convergence/Countries_Wages_Estimates_Finals_GOOD.csv'
df_final.to_csv(output_path, index=False)
print(f"Updated wages file saved to {output_path}")
# Out:
# Updated wages file saved to ~/Documents/Project_Wage_Convergence/Countries_Wages_Estimates_Finals_GOOD.csv

# %%
# create a plot for OECD benchmark vs. our estimate with fancier colors

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# 1. Load our estimated wages (df_final) and OECD raw data
df_final = pd.read_csv(os.path.expanduser('~/Documents/Project_Wage_Convergence/Countries_Wages_Estimates_Finals_GOOD.csv'))
df_oecd  = pd.read_csv(os.path.expanduser('~/Documents/Project_Wage_Convergence/OECD_wages_merged.csv'))

# 2. Rename OECD columns to match df_final keys
df_oecd.rename(columns={
    'Country': 'country',
    'Year':    'year',
    'Wages':   'oecd_annual_wage'
}, inplace=True)
df_oecd['year'] = pd.to_numeric(df_oecd['year'], errors='coerce')

# 3. Merge on country + year
df_compare = pd.merge(
    df_final,
    df_oecd[['country','year','oecd_annual_wage']],
    on=['country','year'],
    how='inner'
)

# 4. Compute OECD hourly wage
df_compare['oecd_hourly_wage'] = df_compare['oecd_annual_wage'] / df_compare['whours']

# 5. Compute yearly averages
avg_wages = df_compare.groupby('year').agg(
    avg_estimated = ('estimated_hourly_wage', 'mean'),
    avg_oecd      = ('oecd_hourly_wage',     'mean')
).reset_index()

# 6. Plot raw-hourly comparison with custom colors
plt.figure(figsize=(10,6))
# use a colormap for two lines
colors = plt.get_cmap('viridis')(np.linspace(0.2, 0.8, 2))
plt.plot(avg_wages['year'], avg_wages['avg_estimated'], marker='o', color=colors[0], linewidth=2, label='Estimated')
plt.plot(avg_wages['year'], avg_wages['avg_oecd'],      marker='x', color=colors[1], linewidth=2, label='OECD')
plt.xlabel('Year')
plt.ylabel('Hourly Wage (PPP)')
plt.title('Average Hourly Wage: Estimate vs OECD')
plt.legend(frameon=True, shadow=True)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
out_raw = os.path.expanduser('~/Downloads/Avg_Hourly_Comparison_GOOD.pdf')
with PdfPages(out_raw) as pdf:
    pdf.savefig()
    plt.close()
print(f"Saved raw comparison to {out_raw}")

# 7. Compute & plot log-transformed averages
avg_wages_log = df_compare.groupby('year').agg(
    log_avg_est = ('estimated_hourly_wage', lambda x: np.log(x).mean()),
    log_avg_oecd= ('oecd_hourly_wage',      lambda x: np.log(x).mean())
).reset_index()

plt.figure(figsize=(10,6))
# use a different colormap
colors2 = plt.get_cmap('plasma')(np.linspace(0.2, 0.8, 2))
plt.plot(avg_wages_log['year'], avg_wages_log['log_avg_est'],  marker='o', color=colors2[0], linewidth=2, label='Log Estimated')
plt.plot(avg_wages_log['year'], avg_wages_log['log_avg_oecd'], marker='x', color=colors2[1], linewidth=2, label='Log OECD')
plt.xlabel('Year')
plt.ylabel('Log Hourly Wage')
plt.title('Log Average Hourly Wage: Estimate vs OECD')
plt.legend(frameon=True, shadow=True)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
out_log = os.path.expanduser('~/Downloads/Log_Hourly_Comparison_GOOD.pdf')
with PdfPages(out_log) as pdf:
    pdf.savefig()
    plt.close()
print(f"Saved log comparison to {out_log}")
# Out:
# Saved raw comparison to /Users/noenotter/Downloads/Avg_Hourly_Comparison_GOOD.pdf
# Saved log comparison to /Users/noenotter/Downloads/Log_Hourly_Comparison_GOOD.pdf
